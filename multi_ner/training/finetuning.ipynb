# %% [markdown]
# # combine BIO tags to spans
#
# save each instance as a jsonl object in gemini 1.5 dataset format for finetuning

# %%
system_instruction2 = """You are a highly specialized biomedical Named Entity Recognition (NER) model, fine-tuned to extract and classify biomedical entities in a manner similar to BERN2. Your task is to process an input text and output a single, valid JSON object with annotations for each entity you detect.

**Task:**
Identify and extract mentions of biomedical entities from the input text and classify each one into exactly one of the following eight entity types:
- `cell_line`
- `cell_type`
- `disease`
- `dna`
- `rna`
- `drug_chemical`
- `gene_protein`
- `species`

For every recognized entity, you must capture the following details:
- `"mention"`: The exact text of the entity.
- `"type"`: The entity type (one of the eight types listed above).
- `"begin"`: The starting character index (0-indexed) where the entity begins in the text.
- `"end"`: The ending character index (exclusive), marking the position immediately after the last character of the entity.

**Output Format:**
Your final output must be a single, valid JSON object with a single key `"annotations"`. The value of `"annotations"` is an array (list) of entity objects, each containing only the keys `"mention"`, `"type"`, `"begin"`, and `"end"`. Do not include any additional keys or text.

**Empty Output:**
If no entities are detected, return exactly:
```json
{"annotations": []}
```

**Example:**
For the input:
```
"In this study, we investigated the effects of aspirin on human platelet function, as well as its interactions with the TP53 gene in Homo sapiens cells in cell lines such as NCI-H1975. Tumor necrosis alpha (TNF-alpha) mRNA production was analyzed by polymerase chain reaction amplification."
```
A correct output would be:
```json
{
  "annotations": [
    {
      "mention": "aspirin",
      "type": "drug_chemical",
      "begin": 46,
      "end": 53
    },
    {
      "mention": "human",
      "type": "species",
      "begin": 57,
      "end": 62
    },
    {
      "mention": "human platelet",
      "type": "cell_type",
      "begin": 57,
      "end": 71
    },
    {
      "mention": "TP53 gene",
      "type": "gene_protein",
      "begin": 119,
      "end": 128
    },
    {
      "mention": "Homo sapiens",
      "type": "species",
      "begin": 132,
      "end": 144
    },
    {
      "mention": "NCI-H1975",
      "type": "cell_line",
      "begin": 173,
      "end": 182
    },
    {
      "mention": "Tumor necrosis alpha (TNF-alpha) mRNA",
      "type": "rna",
      "begin": 184,
      "end": 221
    },
    {
      "mention": "Tumor necrosis alpha",
      "type": "gene",
      "begin": 184,
      "end": 204
    },
    {
      "mention": "TNF-alpha",
      "type": "rna",
      "begin": 206,
      "end": 215
    }
  ]
}
```

**Requirements:**
- All output must be strictly valid JSON.
- Only use the specified keys: `"annotations"`, `"mention"`, `"type"`, `"begin"`, and `"end"`.
- The `"begin"` and `"end"` indices must exactly match the positions of the entity in the input text.
- Output only the JSON object without any additional explanations or formatting.
"""

system_instruction = """You are a highly specialized biomedical Named Entity Recognition (NER) model. Your task is to accurately identify, extract mentions of biomedical entities from text, and classify them into one of the eight types:

1. cell_line
2. cell_type
3. disease
4. dna
5. rna
6. drug_chemical
7. gene_protein
8. species

For each identified entity, you must output a JSON object containing these four keys:

1. "entity": The extracted entity text.
2. "type": The entity type from the list above.
3. "begin": The starting character index of the entity in the input text (0-indexed).
4. "end": The ending character index of the entity in the input text (exclusive, i.e., the index of the character immediately following the entity).

Your output should be a JSON list of these objects, where each object represents a single entity extracted from the input text. If no entities are found, return an empty JSON list.

If no entities are found in the text, return an empty json list:
```json
{"entities": []}

Your output must be in a valid JSON format with this structure:
```json
{
  "entities": [
    {
      "entity": "extracted_entity_text",
      "type": "entity_type",
      "begin": start_index,
      "end": end_index
    },
    ...
  ]
}
```

Do not include any additional commentary or text in your output. Ensure that the JSON is well-formed and follows exactly the format specified above.

Example:

Input Text:
"In this study, we investigated the effects of aspirin on human platelet function, as well as its interactions with the TP53 gene in Homo sapiens cells in cell lines such as NCI-H1975. Tumor necrosis alpha (TNF-alpha) mRNA production was analyzed by polymerase chain reaction amplification."

Output JSON:
```json
[
  {
    "text": "aspirin",
    "type": "drug_chemical",
    "begin": 46,
    "end": 53
  },
  {
    "text": "human",
    "type": "species",
    "begin": 57,
    "end": 62
  },
  {
    "text": "human platelet",
    "type": "cell_type",
    "begin": 57,
    "end": 71
  },
  {
    "text": "TP53 gene",
    "type": "gene_protein",
    "begin": 119,
    "end": 128
  },
  {
    "text": "Homo sapiens",
    "type": "species",
    "begin": 132,
    "end": 144
  },
  {
    "text": "NCI-H1975",
    "type": "cell_line",
    "begin": 173,
    "end": 182
  },
  {
    "text": "Tumor necrosis alpha (TNF-alpha) mRNA",
    "type": "rna",
    "begin": 184,
    "end": 221
  },
  {
    "text": "Tumor necrosis alpha",
    "type": "gene",
    "begin": 184,
    "end": 204
  },
  {
    "text": "TNF-alpha",
    "type": "rna",
    "begin": 206,
    "end": 215
  }
]
```

Input Text:
{input_text}
"""
print(system_instruction)
# Out:
# Your goal is to identify and classify entities into one of the following eight types:
#
# - cell_line
# - cell_type
# - disease
# - dna
# - rna
# - drug_chemical
#  gene_protein
#  species
#
# For each identified entity, you must output a JSON object containing the following keys:
#
#  "entity": The extracted entity text.
#  "type": The entity type from the list above.
#  "begin": The starting character index of the entity in the input text (0-indexed).
# - "end": The ending character index of the entity in the input text (exclusive, i.e., the index of the character immediately following the entity).
#
# Your output should be a JSON list of these objects, where each object represents a single entity extracted from the input text. If no entities are found, return an empty JSON list.
#
# If no entities are found in the text, return an empty list as follows:
# ```json
# {"entities": []}
#
# Your output must be in a valid JSON format with the following structure:
# ```json
# {
#   "entities": [
#     {
#       "entity": "extracted_entity_text",
#       "type": "entity_type",
#       "begin": start_index,
#       "end": end_index
#     },
#     ...
#   ]
# }
#
# Do not include any additional commentary or text in your output. Ensure that the JSON is well-formed and follows exactly the format specified above.
#
# Example:
#
# Input Text:
# "In this study, we investigated the effects of aspirin on human platelet function, as well as its interactions with the TP53 gene in Homo sapiens cells in cell lines such as NCI-H1975."
#
# Output JSON:
# ```json
# [
#   {
#     "text": "aspirin",
#     "label": "drug_chemical",
#     "begin": 46,
#     "end": 53
#   },
#   {
#     "text": "human",
#     "label": "species",
#     "begin": 57,
#     "end": 62
#   },
#   {
#     "text": "platelet",
#     "label": "cell_type",
#     "begin": 63,
#     "end": 71
#   },
#   {
#     "text": "TP53",
#     "label": "gene_protein",
#     "begin": 119,
#     "end": 123
#   },
#   {
#     "text": "Homo sapiens",
#     "label": "species",
#     "begin": 132,
#     "end": 144
#   },
#   {
#     "text": "NCI-H1975",
#     "type": "cell_line",
#     "begin": 173,
#     "end": 183
#   }
# ]

# %%
import re
import json

def detokenize(text):
    # Remove extra space after opening punctuation such as ( [ { <
    text = re.sub(r'([\(\[\{<])\s+', r'\1', text)
    # Remove extra space before closing punctuation such as ) ] } >
    text = re.sub(r'\s+([\)\]\}>])', r'\1', text)
    # Remove extra space before punctuation that should attach to the previous token (e.g., . , ; : ! ?)
    text = re.sub(r'\s+([.,;:!?])', r'\1', text)
    # Remove spaces around hyphens (e.g., "tumour - suppressor" -> "tumour-suppressor")
    text = re.sub(r'\s*-\s*', '-', text)
    # Remove spaces around slashes (e.g., "axin / conductin" -> "axin/conductin")
    text = re.sub(r'\s*/\s*', r'/', text)
    # Remove spaces around percent signs and equals signs
    text = re.sub(r'\s*%\s*', '%', text)
    text = re.sub(r'\s*=\s*', '=', text)
    # Remove spaces between number decimals (e.g., "3 . 14" -> "3.14")
    text = re.sub(r'(\d)\s*\.\s*(\d)', r'\1.\2', text)
    return text

def process_sentence(token_tag_pairs, entity_label):
    """
    Given a list of (token, tag) tuples for a sentence,
    returns the detokenized sentence text and a list of extracted entities.
    Each entity is a dict with keys "text", "label", "begin", and "end".
    """
    # Rebuild the sentence text by joining tokens then detokenize.
    tokens = [tok for tok, tag in token_tag_pairs]
    raw_sentence = " ".join(tokens)
    sentence_text = detokenize(raw_sentence)

    entities = []
    i = 0
    search_start = 0  # pointer for searching entity in sentence_text
    while i < len(token_tag_pairs):
        token, tag = token_tag_pairs[i]
        # Check if token marks beginning of an entity.
        # Support both simple "B" and extended "B-<label>" formats.
        if tag.startswith("B"):
            # Extract label if given (e.g., "B-drug_chemical"); otherwise, default to "entity"
            if '-' in tag:
                _, label = tag.split('-', 1)
            else:
                label = entity_label
            entity_tokens = [token]
            i += 1
            # Collect subsequent tokens with tag starting with "I"
            while i < len(token_tag_pairs) and token_tag_pairs[i][1].startswith("I"):
                entity_tokens.append(token_tag_pairs[i][0])
                i += 1
            # Build the entity text in the same way as the sentence
            raw_entity = " ".join(entity_tokens)
            entity_text = detokenize(raw_entity)
            # Find the entity substring in the sentence text starting from search_start
            pos = sentence_text.find(entity_text, search_start)
            if pos == -1:
                # If not found, you might want to handle this case differently.
                pos = 0
            begin = pos
            end = pos + len(entity_text)
            entities.append({
                "text": entity_text,
                "label": label,
                "begin": begin,
                "end": end
            })
            search_start = end  # update pointer so that subsequent searches start after this entity
        else:
            i += 1
    return sentence_text, entities

def parse_bio_file(file_path):
    """
    Reads a BIO-tagged file with sentences separated by blank lines.
    Returns a list where each element is a list of (token, tag) tuples.
    """
    sentences = []
    current = []

    with open(file_path, 'r', encoding='utf-8') as f:
        for line in f:
            stripped = line.strip()
            if not stripped:
                if current:
                    sentences.append(current)
                    current = []
            else:
                # Expecting each non-blank line to have "token tag"
                parts = stripped.split(maxsplit=1)
                if parts:
                    token = parts[0]
                    tag = parts[1] if len(parts) > 1 else "O"
                    current.append((token, tag))
        if current:
            sentences.append(current)
    return sentences

def create_json_object(sentence_text, entities):
    """
    Creates the JSON object (as a Python dict) for one sentence,
    where the first "parts" contains the sentence text and the second
    contains a string-escaped JSON array of entities.
    """
    # Dump the entities as a pretty JSON string (you can remove indent if desired)
    entities_json_str = json.dumps(entities, indent=2)
    json_obj = {
        "systemInstruction": {
            "role": "system",
            "parts": [
                {
                    "text": system_instruction
                }
            ]
        },
        "contents": [
            {
                "role": "user",
                "parts": [
                    {
                        "text": sentence_text
                    }
                ]
            },
            {
                "role": "model",
                "parts": [
                    {
                        "text": entities_json_str
                    }
                ]
            }
        ]
    }
    return json_obj

def main(input_file, output_file):
    sentences_token_tags = parse_bio_file(input_file)
    with open(output_file, 'w', encoding='utf-8') as out_f:
        for token_tag_pairs in sentences_token_tags:
            sentence_text, entities = process_sentence(token_tag_pairs)
            json_obj = create_json_object(sentence_text, entities)
            # Write each JSON object as one line
            out_f.write(json.dumps(json_obj) + "\n")

# Example usage:
if __name__ == "__main__":
    input_file_path = './NERdata/NCBI-disease/test.txt'  # Replace with your BIO-tagged file path
    output_file_path = './NERdata/NCBI-disease/test_NCBI-disease.jsonl'  # Output JSONL file
    # main(input_file_path, output_file_path)

# %%
import json

# print and verify json array containing entity in gemini 1.5 dataset format
def verify_entities(jsonl_file):
    with open(jsonl_file, 'r', encoding='utf-8') as f:
        for line_number, line in enumerate(f, start=1):
            line = line.strip()
            if not line:
                continue
            try:
                # Load the JSON object from the current line
                json_obj = json.loads(line)
                # Navigate to the second "parts" under "contents"
                # The expected path is: json_obj["contents"][1]["parts"][0]["text"]
                entity_json_str = json_obj["contents"][1]["parts"][0]["text"]
                # Parse the entities JSON string into a Python list/dict
                entities = json.loads(entity_json_str)
                print(f"Entities for JSON object on line {line_number}:")
                print(json.dumps(entities, indent=2))
            except Exception as e:
                print(f"Error processing line {line_number}: {e}")

if __name__ == "__main__":
    jsonl_file = "./NERdata/NCBI-disease/test_NCBI-disease.jsonl"  # Replace with the path to your JSONL file if needed.
    verify_entities(jsonl_file)
# Out:
# Entities for JSON object on line 1:
# [
#   {
#     "text": "ataxia-telangiectasia",
#     "label": "disease",
#     "begin": 40,
#     "end": 61
#   },
#   {
#     "text": "sporadic T-cell leukaemia",
#     "label": "disease",
#     "begin": 72,
#     "end": 97
#   }
# ]
# Entities for JSON object on line 2:
# [
#   {
#     "text": "Ataxia-telangiectasia",
#     "label": "disease",
#     "begin": 0,
#     "end": 21
#   },
#   {
#     "text": "A-T",
#     "label": "disease",
#     "begin": 23,
#     "end": 26
#   },
#   {
#     "text": "recessive multi-system disorder",
#     "label": "disease",
#     "begin": 33,
#     "end": 64
#   }
# ]
# Entities for JSON object on line 3:
# [
#   {
#     "text": "cancer",
#     "label": "disease",
#     "begin": 12,
#     "end": 18
#   },
#   {
#     "text": "lymphoid neoplasias",
#     "label": "disease",
#     "begin": 31,
#     "end": 50
#   },
#   {
#     "text": "A-T",
#     "label": "disease",
#     "begin": 81,
#     "end": 84
#   }
# ]
# Entities for JSON object on line 4:
# [
#   {
#     "text": "tumour",
#     "label": "disease",
#     "begin": 13,
#     "end": 19
#   },
#   {
#     "text": "sporadic T-cell prolymphocytic leukaemia",
#     "label": "disease",
#     "begin": 43,
#     "end": 83
#   },
#   {
#     "text": "T-PLL",
#     "label": "disease",
#     "begin": 85,
#     "end": 90
#   },
#   {
#     "text": "clonal malignancy",
#     "label": "disease",
#     "begin": 100,
#     "end": 117
#   },
#   {
#     "text": "mature T-cell leukaemia",
#     "label": "disease",
#     "begin": 141,
#     "end": 164
#   },
#   {
#     "text": "A-T",
#     "label": "disease",
#     "begin": 173,
#     "end": 176
#   },
#   {
#     "text": "T-PLL",
#     "label": "disease",
#     "begin": 230,
#     "end": 235
#   }
# ]
# Entities for JSON object on line 5:
# [
#   {
#     "text": "A-T",
#     "label": "disease",
#     "begin": 50,
#     "end": 53
#   },
#   {
#     "text": "leukaemia",
#     "label": "disease",
#     "begin": 100,
#     "end": 109
#   }
# ]
# Entities for JSON object on line 6:
# []
# Entities for JSON object on line 7:
# []
# Entities for JSON object on line 8:
# [
#   {
#     "text": "T-PLL",
#     "label": "disease",
#     "begin": 25,
#     "end": 30
#   },
#   {
#     "text": "A-T",
#     "label": "disease",
#     "begin": 65,
#     "end": 68
#   }
# ]
# Entities for JSON object on line 9:
# [
#   {
#     "text": "tumour",
#     "label": "disease",
#     "begin": 78,
#     "end": 84
#   },
#   {
#     "text": "leukaemia",
#     "label": "disease",
#     "begin": 130,
#     "end": 139
#   }
# ]
# Entities for JSON object on line 10:
# [
#   {
#     "text": "tumour",
#     "label": "disease",
#     "begin": 56,
#     "end": 62
#   },
#   {
#     "text": "B-cell non-Hodgkins lymphomas",
#     "label": "disease",
#     "begin": 86,
#     "end": 115
#   },
#   {
#     "text": "B-NHL",
#     "label": "disease",
#     "begin": 117,
#     "end": 122
#   },
#   {
#     "text": "B-NHL",
#     "label": "disease",
#     "begin": 130,
#     "end": 135
#   }
# ]
# Entities for JSON object on line 11:
# [
#   {
#     "text": "tumours",
#     "label": "disease",
#     "begin": 147,
#     "end": 154
#   },
#   {
#     "text": "sporadic T-PLL",
#     "label": "disease",
#     "begin": 224,
#     "end": 238
#   },
#   {
#     "text": "tumour",
#     "label": "disease",
#     "begin": 271,
#     "end": 277
#   }
# ]
# Entities for JSON object on line 12:
# [
#   {
#     "text": "T-PLL",
#     "label": "disease",
#     "begin": 81,
#     "end": 86
#   }
# ]
# Entities for JSON object on line 13:
# [
#   {
#     "text": "Myotonic dystrophy",
#     "label": "disease",
#     "begin": 0,
#     "end": 18
#   }
# ]
# Entities for JSON object on line 14:
# [
#   {
#     "text": "Myotonic dystrophy",
#     "label": "disease",
#     "begin": 0,
#     "end": 18
#   },
#   {
#     "text": "DM",
#     "label": "disease",
#     "begin": 20,
#     "end": 22
#   },
#   {
#     "text": "muscular disorder",
#     "label": "disease",
#     "begin": 44,
#     "end": 61
#   },
#   {
#     "text": "DM",
#     "label": "disease",
#     "begin": 148,
#     "end": 150
#   }
# ]
# Entities for JSON object on line 15:
# []
# Entities for JSON object on line 16:
# []
# Entities for JSON object on line 17:
# []
# Entities for JSON object on line 18:
# []
# Entities for JSON object on line 19:
# []
# Entities for JSON object on line 20:
# []
# Entities for JSON object on line 21:
# [
#   {
#     "text": "unilateral retinoblastoma",
#     "label": "disease",
#     "begin": 60,
#     "end": 85
#   }
# ]
# Entities for JSON object on line 22:
# [
#   {
#     "text": "unilateral retinoblastoma",
#     "label": "disease",
#     "begin": 31,
#     "end": 56
#   },
#   {
#     "text": "tumor",
#     "label": "disease",
#     "begin": 58,
#     "end": 63
#   }
# ]
# Entities for JSON object on line 23:
# [
#   {
#     "text": "retinoblastoma",
#     "label": "disease",
#     "begin": 45,
#     "end": 59
#   }
# ]
# Entities for JSON object on line 24:
# [
#   {
#     "text": "unilateral retinoblastoma",
#     "label": "disease",
#     "begin": 101,
#     "end": 126
#   },
#   {
#     "text": "tumor",
#     "label": "disease",
#     "begin": 175,
#     "end": 180
#   }
# ]
# Entities for JSON object on line 25:
# [
#   {
#     "text": "tumors",
#     "label": "disease",
#     "begin": 16,
#     "end": 22
#   }
# ]
# Entities for JSON object on line 26:
# []
# Entities for JSON object on line 27:
# [
#   {
#     "text": "tumors",
#     "label": "disease",
#     "begin": 25,
#     "end": 31
#   }
# ]
# Entities for JSON object on line 28:
# [
#   {
#     "text": "tumors",
#     "label": "disease",
#     "begin": 42,
#     "end": 48
#   }
# ]
# Entities for JSON object on line 29:
# [
#   {
#     "text": "tumors",
#     "label": "disease",
#     "begin": 17,
#     "end": 23
#   },
#   {
#     "text": "tumors",
#     "label": "disease",
#     "begin": 86,
#     "end": 92
#   }
# ]
# Entities for JSON object on line 30:
# [
#   {
#     "text": "tumors",
#     "label": "disease",
#     "begin": 49,
#     "end": 55
#   }
# ]
# Entities for JSON object on line 31:
# []
# Entities for JSON object on line 32:
# []
# Entities for JSON object on line 33:
# []
# Entities for JSON object on line 34:
# []
# Entities for JSON object on line 35:
# [
#   {
#     "text": "tumors",
#     "label": "disease",
#     "begin": 133,
#     "end": 139
#   },
#   {
#     "text": "bilateral retinoblastoma",
#     "label": "disease",
#     "begin": 170,
#     "end": 194
#   }
# ]
# Entities for JSON object on line 36:
# [
#   {
#     "text": "retinoblastoma",
#     "label": "disease",
#     "begin": 84,
#     "end": 98
#   }
# ]
# Entities for JSON object on line 37:
# [
#   {
#     "text": "Hereditary deficiency of the fifth component of complement",
#     "label": "disease",
#     "begin": 0,
#     "end": 58
#   }
# ]
# Entities for JSON object on line 38:
# []
# Entities for JSON object on line 39:
# []
# Entities for JSON object on line 40:
# [
#   {
#     "text": "hereditary deficiency of the fifth component of complement",
#     "label": "disease",
#     "begin": 40,
#     "end": 98
#   }
# ]
# Entities for JSON object on line 41:
# [
#   {
#     "text": "systemic lupus erythematosus",
#     "label": "disease",
#     "begin": 45,
#     "end": 73
#   }
# ]
# Entities for JSON object on line 42:
# []
# Entities for JSON object on line 43:
# []
# Entities for JSON object on line 44:
# []
# Entities for JSON object on line 45:
# []
# Entities for JSON object on line 46:
# [
#   {
#     "text": "C5 deficiency",
#     "label": "disease",
#     "begin": 156,
#     "end": 169
#   }
# ]
# Entities for JSON object on line 47:
# [
#   {
#     "text": "C5-deficient",
#     "label": "disease",
#     "begin": 57,
#     "end": 69
#   },
#   {
#     "text": "C5D",
#     "label": "disease",
#     "begin": 71,
#     "end": 74
#   }
# ]
# Entities for JSON object on line 48:
# [
#   {
#     "text": "C5D",
#     "label": "disease",
#     "begin": 137,
#     "end": 140
#   }
# ]
# Entities for JSON object on line 49:
# [
#   {
#     "text": "C5D",
#     "label": "disease",
#     "begin": 48,
#     "end": 51
#   }
# ]
# Entities for JSON object on line 50:
# [
#   {
#     "text": "glomerulonephritis",
#     "label": "disease",
#     "begin": 61,
#     "end": 79
#   },
#   {
#     "text": "vasculitis",
#     "label": "disease",
#     "begin": 81,
#     "end": 91
#   },
#   {
#     "text": "arthritis",
#     "label": "disease",
#     "begin": 97,
#     "end": 106
#   },
#   {
#     "text": "bacterial infections",
#     "label": "disease",
#     "begin": 200,
#     "end": 220
#   }
# ]
# Entities for JSON object on line 51:
# [
#   {
#     "text": "C5D",
#     "label": "disease",
#     "begin": 37,
#     "end": 40
#   },
#   {
#     "text": "pyogenic infection",
#     "label": "disease",
#     "begin": 155,
#     "end": 173
#   }
# ]
# Entities for JSON object on line 52:
# [
#   {
#     "text": "ankylosing spondylitis",
#     "label": "disease",
#     "begin": 18,
#     "end": 40
#   }
# ]
# Entities for JSON object on line 53:
# [
#   {
#     "text": "ankylosing spondylitis",
#     "label": "disease",
#     "begin": 102,
#     "end": 124
#   },
#   {
#     "text": "AS",
#     "label": "disease",
#     "begin": 126,
#     "end": 128
#   }
# ]
# Entities for JSON object on line 54:
# [
#   {
#     "text": "AS",
#     "label": "disease",
#     "begin": 19,
#     "end": 21
#   },
#   {
#     "text": "Rheumatic Diseases",
#     "label": "disease",
#     "begin": 75,
#     "end": 93
#   }
# ]
# Entities for JSON object on line 55:
# []
# Entities for JSON object on line 56:
# []
# Entities for JSON object on line 57:
# [
#   {
#     "text": "AS",
#     "label": "disease",
#     "begin": 137,
#     "end": 139
#   }
# ]
# Entities for JSON object on line 58:
# []
# Entities for JSON object on line 59:
# []
# Entities for JSON object on line 60:
# []
# Entities for JSON object on line 61:
# []
# Entities for JSON object on line 62:
# [
#   {
#     "text": "AS",
#     "label": "disease",
#     "begin": 29,
#     "end": 31
#   }
# ]
# Entities for JSON object on line 63:
# [
#   {
#     "text": "AS",
#     "label": "disease",
#     "begin": 73,
#     "end": 75
#   }
# ]
# Entities for JSON object on line 64:
# []
# Entities for JSON object on line 65:
# [
#   {
#     "text": "breast and ovarian cancer",
#     "label": "disease",
#     "begin": 70,
#     "end": 95
#   },
#   {
#     "text": "tumor",
#     "label": "disease",
#     "begin": 148,
#     "end": 153
#   }
# ]
# Entities for JSON object on line 66:
# []
# Entities for JSON object on line 67:
# []
# Entities for JSON object on line 68:
# []
# Entities for JSON object on line 69:
# []
# Entities for JSON object on line 70:
# []
# Entities for JSON object on line 71:
# []
# Entities for JSON object on line 72:
# []
# Entities for JSON object on line 73:
# []
# Entities for JSON object on line 74:
# [
#   {
#     "text": "tumor",
#     "label": "disease",
#     "begin": 105,
#     "end": 110
#   }
# ]
# Entities for JSON object on line 75:
# []
# Entities for JSON object on line 76:
# [
#   {
#     "text": "hereditary hemochromatosis",
#     "label": "disease",
#     "begin": 31,
#     "end": 57
#   },
#   {
#     "text": "HH",
#     "label": "disease",
#     "begin": 59,
#     "end": 61
#   }
# ]
# Entities for JSON object on line 77:
# []
# Entities for JSON object on line 78:
# []
# Entities for JSON object on line 79:
# []
# Entities for JSON object on line 80:
# []
# Entities for JSON object on line 81:
# []
# Entities for JSON object on line 82:
# []
# Entities for JSON object on line 83:
# [
#   {
#     "text": "HH",
#     "label": "disease",
#     "begin": 69,
#     "end": 71
#   }
# ]
# Entities for JSON object on line 84:
# [
#   {
#     "text": "HH",
#     "label": "disease",
#     "begin": 75,
#     "end": 77
#   },
#   {
#     "text": "cancer",
#     "label": "disease",
#     "begin": 178,
#     "end": 184
#   }
# ]
# Entities for JSON object on line 85:
# [
#   {
#     "text": "Autosomal dominant neurohypophyseal diabetes insipidus",
#     "label": "disease",
#     "begin": 0,
#     "end": 54
#   }
# ]
# Entities for JSON object on line 86:
# [
#   {
#     "text": "Autosomal dominant neurohypophyseal diabetes insipidus",
#     "label": "disease",
#     "begin": 0,
#     "end": 54
#   },
#   {
#     "text": "ADNDI",
#     "label": "disease",
#     "begin": 56,
#     "end": 61
#   },
#   {
#     "text": "inherited disease",
#     "label": "disease",
#     "begin": 69,
#     "end": 86
#   }
# ]
# Entities for JSON object on line 87:
# [
#   {
#     "text": "diabetes insipidus",
#     "label": "disease",
#     "begin": 71,
#     "end": 89
#   }
# ]
# Entities for JSON object on line 88:
# [
#   {
#     "text": "ADNDI",
#     "label": "disease",
#     "begin": 97,
#     "end": 102
#   }
# ]
# Entities for JSON object on line 89:
# []
# Entities for JSON object on line 90:
# []
# Entities for JSON object on line 91:
# []
# Entities for JSON object on line 92:
# [
#   {
#     "text": "dominantly inherited neurodegeneration",
#     "label": "disease",
#     "begin": 55,
#     "end": 93
#   }
# ]
# Entities for JSON object on line 93:
# [
#   {
#     "text": "prostate cancer",
#     "label": "disease",
#     "begin": 47,
#     "end": 62
#   }
# ]
# Entities for JSON object on line 94:
# [
#   {
#     "text": "Sporadic prostate carcinoma",
#     "label": "disease",
#     "begin": 0,
#     "end": 27
#   },
#   {
#     "text": "male cancer",
#     "label": "disease",
#     "begin": 47,
#     "end": 58
#   },
#   {
#     "text": "cancer",
#     "label": "disease",
#     "begin": 166,
#     "end": 172
#   }
# ]
# Entities for JSON object on line 95:
# [
#   {
#     "text": "sporadic prostate cancer",
#     "label": "disease",
#     "begin": 116,
#     "end": 140
#   }
# ]
# Entities for JSON object on line 96:
# []
# Entities for JSON object on line 97:
# [
#   {
#     "text": "tumor",
#     "label": "disease",
#     "begin": 6,
#     "end": 11
#   },
#   {
#     "text": "prostate cancer",
#     "label": "disease",
#     "begin": 147,
#     "end": 162
#   }
# ]
# Entities for JSON object on line 98:
# [
#   {
#     "text": "prostate tumors",
#     "label": "disease",
#     "begin": 15,
#     "end": 30
#   }
# ]
# Entities for JSON object on line 99:
# []
# Entities for JSON object on line 100:
# [
#   {
#     "text": "tumors",
#     "label": "disease",
#     "begin": 62,
#     "end": 68
#   },
#   {
#     "text": "sporadic prostate cancer",
#     "label": "disease",
#     "begin": 137,
#     "end": 161
#   }
# ]
# Entities for JSON object on line 101:
# [
#   {
#     "text": "Huntington disease",
#     "label": "disease",
#     "begin": 41,
#     "end": 59
#   }
# ]
# Entities for JSON object on line 102:
# [
#   {
#     "text": "Huntington disease",
#     "label": "disease",
#     "begin": 33,
#     "end": 51
#   },
#   {
#     "text": "HD",
#     "label": "disease",
#     "begin": 53,
#     "end": 55
#   },
#   {
#     "text": "HD",
#     "label": "disease",
#     "begin": 171,
#     "end": 173
#   }
# ]
# Entities for JSON object on line 103:
# []
# Entities for JSON object on line 104:
# [
#   {
#     "text": "HD",
#     "label": "disease",
#     "begin": 26,
#     "end": 28
#   }
# ]
# Entities for JSON object on line 105:
# []
# Entities for JSON object on line 106:
# []
# Entities for JSON object on line 107:
# []
# Entities for JSON object on line 108:
# [
#   {
#     "text": "mucopolysaccharidosis IVA",
#     "label": "disease",
#     "begin": 96,
#     "end": 121
#   }
# ]
# Entities for JSON object on line 109:
# [
#   {
#     "text": "Mucopolysaccharidosis IVA",
#     "label": "disease",
#     "begin": 0,
#     "end": 25
#   },
#   {
#     "text": "MPS IVA",
#     "label": "disease",
#     "begin": 27,
#     "end": 34
#   },
#   {
#     "text": "autosomal recessive lysosomal storage disorder",
#     "label": "disease",
#     "begin": 42,
#     "end": 88
#   },
#   {
#     "text": "genetic defect",
#     "label": "disease",
#     "begin": 101,
#     "end": 115
#   }
# ]
# Entities for JSON object on line 110:
# []
# Entities for JSON object on line 111:
# [
#   {
#     "text": "MPS IVA",
#     "label": "disease",
#     "begin": 107,
#     "end": 114
#   }
# ]
# Entities for JSON object on line 112:
# [
#   {
#     "text": "MPS IVA",
#     "label": "disease",
#     "begin": 116,
#     "end": 123
#   }
# ]
# Entities for JSON object on line 113:
# []
# Entities for JSON object on line 114:
# []
# Entities for JSON object on line 115:
# []
# Entities for JSON object on line 116:
# []
# Entities for JSON object on line 117:
# []
# Entities for JSON object on line 118:
# []
# Entities for JSON object on line 119:
# [
#   {
#     "text": "breast/ovarian cancer",
#     "label": "disease",
#     "begin": 55,
#     "end": 76
#   }
# ]
# Entities for JSON object on line 120:
# [
#   {
#     "text": "breast/ovarian cancer",
#     "label": "disease",
#     "begin": 40,
#     "end": 61
#   }
# ]
# Entities for JSON object on line 121:
# [
#   {
#     "text": "breast cancer",
#     "label": "disease",
#     "begin": 47,
#     "end": 60
#   },
#   {
#     "text": "breast-ovarian cancer",
#     "label": "disease",
#     "begin": 81,
#     "end": 102
#   }
# ]
# Entities for JSON object on line 122:
# []
# Entities for JSON object on line 123:
# []
# Entities for JSON object on line 124:
# []
# Entities for JSON object on line 125:
# []
# Entities for JSON object on line 126:
# []
# Entities for JSON object on line 127:
# []
# Entities for JSON object on line 128:
# [
#   {
#     "text": "breast/ovarian cancer",
#     "label": "disease",
#     "begin": 68,
#     "end": 89
#   }
# ]
# Entities for JSON object on line 129:
# [
#   {
#     "text": "congenital myotonic dystrophy",
#     "label": "disease",
#     "begin": 25,
#     "end": 54
#   }
# ]
# Entities for JSON object on line 130:
# [
#   {
#     "text": "congenital myotonic dystrophy",
#     "label": "disease",
#     "begin": 48,
#     "end": 77
#   },
#   {
#     "text": "DM",
#     "label": "disease",
#     "begin": 79,
#     "end": 81
#   }
# ]
# Entities for JSON object on line 131:
# [
#   {
#     "text": "mentally retarded",
#     "label": "disease",
#     "begin": 30,
#     "end": 47
#   },
#   {
#     "text": "muscular weakness",
#     "label": "disease",
#     "begin": 72,
#     "end": 89
#   }
# ]
# Entities for JSON object on line 132:
# []
# Entities for JSON object on line 133:
# [
#   {
#     "text": "DM",
#     "label": "disease",
#     "begin": 41,
#     "end": 43
#   }
# ]
# Entities for JSON object on line 134:
# [
#   {
#     "text": "DM",
#     "label": "disease",
#     "begin": 40,
#     "end": 42
#   }
# ]
# Entities for JSON object on line 135:
# [
#   {
#     "text": "congenital DM",
#     "label": "disease",
#     "begin": 49,
#     "end": 62
#   }
# ]
# Entities for JSON object on line 136:
# [
#   {
#     "text": "congenital DM",
#     "label": "disease",
#     "begin": 53,
#     "end": 66
#   }
# ]
# Entities for JSON object on line 137:
# [
#   {
#     "text": "DM",
#     "label": "disease",
#     "begin": 46,
#     "end": 48
#   },
#   {
#     "text": "congenital DM",
#     "label": "disease",
#     "begin": 173,
#     "end": 186
#   }
# ]
# Entities for JSON object on line 138:
# [
#   {
#     "text": "congenital DM",
#     "label": "disease",
#     "begin": 185,
#     "end": 198
#   }
# ]
# Entities for JSON object on line 139:
# [
#   {
#     "text": "congenital DM",
#     "label": "disease",
#     "begin": 42,
#     "end": 55
#   },
#   {
#     "text": "DM",
#     "label": "disease",
#     "begin": 104,
#     "end": 106
#   }
# ]
# Entities for JSON object on line 140:
# [
#   {
#     "text": "ectopic intracranial retinoblastoma",
#     "label": "disease",
#     "begin": 38,
#     "end": 73
#   }
# ]
# Entities for JSON object on line 141:
# [
#   {
#     "text": "ectopic intracranial retinoblastoma",
#     "label": "disease",
#     "begin": 55,
#     "end": 90
#   },
#   {
#     "text": "pineal and retinal tumours",
#     "label": "disease",
#     "begin": 124,
#     "end": 150
#   }
# ]
# Entities for JSON object on line 142:
# [
#   {
#     "text": "retinal and the pineal tumours",
#     "label": "disease",
#     "begin": 108,
#     "end": 138
#   }
# ]
# Entities for JSON object on line 143:
# []
# Entities for JSON object on line 144:
# []
# Entities for JSON object on line 145:
# [
#   {
#     "text": "retinoblastoma",
#     "label": "disease",
#     "begin": 146,
#     "end": 160
#   }
# ]
# Entities for JSON object on line 146:
# []
# Entities for JSON object on line 147:
# [
#   {
#     "text": "melanoma",
#     "label": "disease",
#     "begin": 102,
#     "end": 110
#   },
#   {
#     "text": "deficiency of hex A",
#     "label": "disease",
#     "begin": 173,
#     "end": 192
#   },
#   {
#     "text": "Tay-Sachs disease",
#     "label": "disease",
#     "begin": 247,
#     "end": 264
#   },
#   {
#     "text": "TSD",
#     "label": "disease",
#     "begin": 266,
#     "end": 269
#   }
# ]
# Entities for JSON object on line 148:
# []
# Entities for JSON object on line 149:
# []
# Entities for JSON object on line 150:
# []
# Entities for JSON object on line 151:
# [
#   {
#     "text": "TSD",
#     "label": "disease",
#     "begin": 109,
#     "end": 112
#   }
# ]
# Entities for JSON object on line 152:
# []
# Entities for JSON object on line 153:
# [
#   {
#     "text": "TSD",
#     "label": "disease",
#     "begin": 93,
#     "end": 96
#   }
# ]
# Entities for JSON object on line 154:
# [
#   {
#     "text": "TSD",
#     "label": "disease",
#     "begin": 130,
#     "end": 133
#   },
#   {
#     "text": "hex A deficiency",
#     "label": "disease",
#     "begin": 167,
#     "end": 183
#   }
# ]
# Entities for JSON object on line 155:
# [
#   {
#     "text": "tumor",
#     "label": "disease",
#     "begin": 4,
#     "end": 9
#   }
# ]
# Entities for JSON object on line 156:
# [
#   {
#     "text": "tumor",
#     "label": "disease",
#     "begin": 28,
#     "end": 33
#   },
#   {
#     "text": "pancreatic cancers",
#     "label": "disease",
#     "begin": 131,
#     "end": 149
#   }
# ]
# Entities for JSON object on line 157:
# []
# Entities for JSON object on line 158:
# []
# Entities for JSON object on line 159:
# []
# Entities for JSON object on line 160:
# [
#   {
#     "text": "Growth retardation",
#     "label": "disease",
#     "begin": 0,
#     "end": 18
#   }
# ]
# Entities for JSON object on line 161:
# [
#   {
#     "text": "gastrulation defect",
#     "label": "disease",
#     "begin": 83,
#     "end": 102
#   }
# ]
# Entities for JSON object on line 162:
# [
#   {
#     "text": "gastrulation defect",
#     "label": "disease",
#     "begin": 118,
#     "end": 137
#   }
# ]
# Entities for JSON object on line 163:
# []
# Entities for JSON object on line 164:
# [
#   {
#     "text": "melanoma",
#     "label": "disease",
#     "begin": 52,
#     "end": 60
#   }
# ]
# Entities for JSON object on line 165:
# [
#   {
#     "text": "Familial Melanoma",
#     "label": "disease",
#     "begin": 11,
#     "end": 28
#   }
# ]
# Entities for JSON object on line 166:
# [
#   {
#     "text": "melanoma",
#     "label": "disease",
#     "begin": 79,
#     "end": 87
#   }
# ]
# Entities for JSON object on line 167:
# [
#   {
#     "text": "melanoma",
#     "label": "disease",
#     "begin": 53,
#     "end": 61
#   }
# ]
# Entities for JSON object on line 168:
# []
# Entities for JSON object on line 169:
# []
# Entities for JSON object on line 170:
# [
#   {
#     "text": "familial melanoma",
#     "label": "disease",
#     "begin": 69,
#     "end": 86
#   },
#   {
#     "text": "melanoma",
#     "label": "disease",
#     "begin": 130,
#     "end": 138
#   }
# ]
# Entities for JSON object on line 171:
# [
#   {
#     "text": "myotonic dystrophy",
#     "label": "disease",
#     "begin": 77,
#     "end": 95
#   }
# ]
# Entities for JSON object on line 172:
# [
#   {
#     "text": "myotonic dystrophy",
#     "label": "disease",
#     "begin": 21,
#     "end": 39
#   },
#   {
#     "text": "DM",
#     "label": "disease",
#     "begin": 41,
#     "end": 43
#   },
#   {
#     "text": "DM",
#     "label": "disease",
#     "begin": 109,
#     "end": 111
#   }
# ]
# Entities for JSON object on line 173:
# [
#   {
#     "text": "DM",
#     "label": "disease",
#     "begin": 37,
#     "end": 39
#   }
# ]
# Entities for JSON object on line 174:
# []
# Entities for JSON object on line 175:
# []
# Entities for JSON object on line 176:
# [
#   {
#     "text": "DM",
#     "label": "disease",
#     "begin": 49,
#     "end": 51
#   },
#   {
#     "text": "myotonic dystrophy",
#     "label": "disease",
#     "begin": 139,
#     "end": 157
#   }
# ]
# Entities for JSON object on line 177:
# []
# Entities for JSON object on line 178:
# []
# Entities for JSON object on line 179:
# [
#   {
#     "text": "Aspartylglucosaminuria",
#     "label": "disease",
#     "begin": 0,
#     "end": 22
#   }
# ]
# Entities for JSON object on line 180:
# [
#   {
#     "text": "Aspartylglucosaminuria",
#     "label": "disease",
#     "begin": 0,
#     "end": 22
#   },
#   {
#     "text": "AGU",
#     "label": "disease",
#     "begin": 24,
#     "end": 27
#   },
#   {
#     "text": "disorder of glycoprotein metabolism",
#     "label": "disease",
#     "begin": 39,
#     "end": 74
#   },
#   {
#     "text": "deficiency of the lysosomal enzyme aspartylglucosaminidase",
#     "label": "disease",
#     "begin": 89,
#     "end": 147
#   }
# ]
# Entities for JSON object on line 181:
# [
#   {
#     "text": "AGU",
#     "label": "disease",
#     "begin": 0,
#     "end": 3
#   }
# ]
# Entities for JSON object on line 182:
# [
#   {
#     "text": "AGU",
#     "label": "disease",
#     "begin": 29,
#     "end": 32
#   }
# ]
# Entities for JSON object on line 183:
# [
#   {
#     "text": "AGU",
#     "label": "disease",
#     "begin": 26,
#     "end": 29
#   }
# ]
# Entities for JSON object on line 184:
# []
# Entities for JSON object on line 185:
# [
#   {
#     "text": "ataxia-telangiectasia",
#     "label": "disease",
#     "begin": 42,
#     "end": 63
#   }
# ]
# Entities for JSON object on line 186:
# [
#   {
#     "text": "ataxia-telangiectasia",
#     "label": "disease",
#     "begin": 3,
#     "end": 24
#   },
#   {
#     "text": "A-T",
#     "label": "disease",
#     "begin": 26,
#     "end": 29
#   },
#   {
#     "text": "autosomal recessive syndrome",
#     "label": "disease",
#     "begin": 87,
#     "end": 115
#   },
#   {
#     "text": "malignancy",
#     "label": "disease",
#     "begin": 232,
#     "end": 242
#   }
# ]
# Entities for JSON object on line 187:
# [
#   {
#     "text": "A-T",
#     "label": "disease",
#     "begin": 62,
#     "end": 65
#   },
#   {
#     "text": "cancer",
#     "label": "disease",
#     "begin": 77,
#     "end": 83
#   }
# ]
# Entities for JSON object on line 188:
# [
#   {
#     "text": "A-T",
#     "label": "disease",
#     "begin": 83,
#     "end": 86
#   },
#   {
#     "text": "A-T",
#     "label": "disease",
#     "begin": 109,
#     "end": 112
#   }
# ]
# Entities for JSON object on line 189:
# [
#   {
#     "text": "A-T",
#     "label": "disease",
#     "begin": 5,
#     "end": 8
#   }
# ]
# Entities for JSON object on line 190:
# [
#   {
#     "text": "A-T",
#     "label": "disease",
#     "begin": 105,
#     "end": 108
#   }
# ]
# Entities for JSON object on line 191:
# [
#   {
#     "text": "familial and sporadic cancers",
#     "label": "disease",
#     "begin": 88,
#     "end": 117
#   },
#   {
#     "text": "tumor",
#     "label": "disease",
#     "begin": 190,
#     "end": 195
#   }
# ]
# Entities for JSON object on line 192:
# [
#   {
#     "text": "Ataxia-telangiectasia",
#     "label": "disease",
#     "begin": 0,
#     "end": 21
#   }
# ]
# Entities for JSON object on line 193:
# [
#   {
#     "text": "breast cancer",
#     "label": "disease",
#     "begin": 96,
#     "end": 109
#   },
#   {
#     "text": "ataxia-telangiectasia",
#     "label": "disease",
#     "begin": 190,
#     "end": 211
#   },
#   {
#     "text": "A-T",
#     "label": "disease",
#     "begin": 213,
#     "end": 216
#   }
# ]
# Entities for JSON object on line 194:
# []
# Entities for JSON object on line 195:
# []
# Entities for JSON object on line 196:
# []
# Entities for JSON object on line 197:
# []
# Entities for JSON object on line 198:
# []
# Entities for JSON object on line 199:
# []
# Entities for JSON object on line 200:
# [
#   {
#     "text": "A-T",
#     "label": "disease",
#     "begin": 45,
#     "end": 48
#   }
# ]
# Entities for JSON object on line 201:
# [
#   {
#     "text": "von Hippel-Lindau tumor",
#     "label": "disease",
#     "begin": 4,
#     "end": 27
#   }
# ]
# Entities for JSON object on line 202:
# [
#   {
#     "text": "von Hippel-Lindau (VHL) tumor",
#     "label": "disease",
#     "begin": 24,
#     "end": 53
#   },
#   {
#     "text": "VHL cancer syndrome",
#     "label": "disease",
#     "begin": 116,
#     "end": 135
#   },
#   {
#     "text": "sporadic renal cell carcinomas",
#     "label": "disease",
#     "begin": 159,
#     "end": 189
#   },
#   {
#     "text": "RCC",
#     "label": "disease",
#     "begin": 191,
#     "end": 194
#   },
#   {
#     "text": "brain hemangioblastomas",
#     "label": "disease",
#     "begin": 200,
#     "end": 223
#   }
# ]
# Entities for JSON object on line 203:
# [
#   {
#     "text": "RCC",
#     "label": "disease",
#     "begin": 19,
#     "end": 22
#   },
#   {
#     "text": "VHL",
#     "label": "disease",
#     "begin": 103,
#     "end": 106
#   }
# ]
# Entities for JSON object on line 204:
# []
# Entities for JSON object on line 205:
# [
#   {
#     "text": "cancer",
#     "label": "disease",
#     "begin": 31,
#     "end": 37
#   }
# ]
# Entities for JSON object on line 206:
# [
#   {
#     "text": "VHL",
#     "label": "disease",
#     "begin": 55,
#     "end": 58
#   },
#   {
#     "text": "RCC cancer",
#     "label": "disease",
#     "begin": 101,
#     "end": 111
#   }
# ]
# Entities for JSON object on line 207:
# [
#   {
#     "text": "RCC",
#     "label": "disease",
#     "begin": 35,
#     "end": 38
#   }
# ]
# Entities for JSON object on line 208:
# [
#   {
#     "text": "VHL",
#     "label": "disease",
#     "begin": 103,
#     "end": 106
#   }
# ]
# Entities for JSON object on line 209:
# [
#   {
#     "text": "VHL",
#     "label": "disease",
#     "begin": 38,
#     "end": 41
#   },
#   {
#     "text": "tumor",
#     "label": "disease",
#     "begin": 139,
#     "end": 144
#   }
# ]
# Entities for JSON object on line 210:
# [
#   {
#     "text": "VHL",
#     "label": "disease",
#     "begin": 53,
#     "end": 56
#   },
#   {
#     "text": "VHL",
#     "label": "disease",
#     "begin": 70,
#     "end": 73
#   },
#   {
#     "text": "tumor",
#     "label": "disease",
#     "begin": 87,
#     "end": 92
#   }
# ]
# Entities for JSON object on line 211:
# [
#   {
#     "text": "Piebaldism",
#     "label": "disease",
#     "begin": 0,
#     "end": 10
#   },
#   {
#     "text": "deafness",
#     "label": "disease",
#     "begin": 16,
#     "end": 24
#   }
# ]
# Entities for JSON object on line 212:
# [
#   {
#     "text": "piebaldism",
#     "label": "disease",
#     "begin": 51,
#     "end": 61
#   },
#   {
#     "text": "sensorineural deafness",
#     "label": "disease",
#     "begin": 86,
#     "end": 108
#   }
# ]
# Entities for JSON object on line 213:
# [
#   {
#     "text": "auditory anomalies",
#     "label": "disease",
#     "begin": 7,
#     "end": 25
#   },
#   {
#     "text": "deafness",
#     "label": "disease",
#     "begin": 108,
#     "end": 116
#   },
#   {
#     "text": "piebaldism",
#     "label": "disease",
#     "begin": 141,
#     "end": 151
#   }
# ]
# Entities for JSON object on line 214:
# [
#   {
#     "text": "sensorineural deafness",
#     "label": "disease",
#     "begin": 24,
#     "end": 46
#   },
#   {
#     "text": "piebaldism",
#     "label": "disease",
#     "begin": 108,
#     "end": 118
#   },
#   {
#     "text": "piebaldism",
#     "label": "disease",
#     "begin": 199,
#     "end": 209
#   },
#   {
#     "text": "Waardenburg syndrome",
#     "label": "disease",
#     "begin": 235,
#     "end": 255
#   }
# ]
# Entities for JSON object on line 215:
# [
#   {
#     "text": "atrophic benign epidermolysis bullosa",
#     "label": "disease",
#     "begin": 154,
#     "end": 191
#   }
# ]
# Entities for JSON object on line 216:
# [
#   {
#     "text": "atrophic benign epidermolysis bullosa",
#     "label": "disease",
#     "begin": 26,
#     "end": 63
#   }
# ]
# Entities for JSON object on line 217:
# [
#   {
#     "text": "atrophic benign epidermolysis bullosa",
#     "label": "disease",
#     "begin": 92,
#     "end": 129
#   }
# ]
# Entities for JSON object on line 218:
# []
# Entities for JSON object on line 219:
# []
# Entities for JSON object on line 220:
# []
# Entities for JSON object on line 221:
# []
# Entities for JSON object on line 222:
# []
# Entities for JSON object on line 223:
# []
# Entities for JSON object on line 224:
# []
# Entities for JSON object on line 225:
# [
#   {
#     "text": "atrophic benign epidermolysis bullosa",
#     "label": "disease",
#     "begin": 74,
#     "end": 111
#   }
# ]
# Entities for JSON object on line 226:
# [
#   {
#     "text": "atrophic benign epidermolysis bullosa",
#     "label": "disease",
#     "begin": 26,
#     "end": 63
#   },
#   {
#     "text": "junctional epidermolysis bullosa",
#     "label": "disease",
#     "begin": 93,
#     "end": 125
#   },
#   {
#     "text": "blistering",
#     "label": "disease",
#     "begin": 144,
#     "end": 154
#   },
#   {
#     "text": "nail dystrophy",
#     "label": "disease",
#     "begin": 156,
#     "end": 170
#   },
#   {
#     "text": "patchy alopecia",
#     "label": "disease",
#     "begin": 172,
#     "end": 187
#   },
#   {
#     "text": "dental abnormalities",
#     "label": "disease",
#     "begin": 193,
#     "end": 213
#   }
# ]
# Entities for JSON object on line 227:
# [
#   {
#     "text": "Skin fragility",
#     "label": "disease",
#     "begin": 0,
#     "end": 14
#   }
# ]
# Entities for JSON object on line 228:
# [
#   {
#     "text": "atrophic benign epidermolysis bullosa",
#     "label": "disease",
#     "begin": 62,
#     "end": 99
#   }
# ]
# Entities for JSON object on line 229:
# []
# Entities for JSON object on line 230:
# []
# Entities for JSON object on line 231:
# []
# Entities for JSON object on line 232:
# []
# Entities for JSON object on line 233:
# []
# Entities for JSON object on line 234:
# []
# Entities for JSON object on line 235:
# []
# Entities for JSON object on line 236:
# []
# Entities for JSON object on line 237:
# [
#   {
#     "text": "anhaptoglobinemia",
#     "label": "disease",
#     "begin": 46,
#     "end": 63
#   }
# ]
# Entities for JSON object on line 238:
# [
#   {
#     "text": "anhaptoglobinemia",
#     "label": "disease",
#     "begin": 87,
#     "end": 104
#   }
# ]
# Entities for JSON object on line 239:
# []
# Entities for JSON object on line 240:
# [
#   {
#     "text": "anhaptoglobinemia",
#     "label": "disease",
#     "begin": 71,
#     "end": 88
#   }
# ]
# Entities for JSON object on line 241:
# [
#   {
#     "text": "hypohaptoglobinemia",
#     "label": "disease",
#     "begin": 45,
#     "end": 64
#   }
# ]
# Entities for JSON object on line 242:
# [
#   {
#     "text": "hypohaptoglobinemic",
#     "label": "disease",
#     "begin": 84,
#     "end": 103
#   },
#   {
#     "text": "hypohaptoglobinemic",
#     "label": "disease",
#     "begin": 191,
#     "end": 210
#   }
# ]
# Entities for JSON object on line 243:
# []
# Entities for JSON object on line 244:
# []
# Entities for JSON object on line 245:
# []
# Entities for JSON object on line 246:
# []
# Entities for JSON object on line 247:
# [
#   {
#     "text": "anhaptoglobinemia",
#     "label": "disease",
#     "begin": 52,
#     "end": 69
#   }
# ]
# Entities for JSON object on line 248:
# [
#   {
#     "text": "hypohaptoglobinemia",
#     "label": "disease",
#     "begin": 26,
#     "end": 45
#   }
# ]
# Entities for JSON object on line 249:
# [
#   {
#     "text": "ataxia-telangiectasia",
#     "label": "disease",
#     "begin": 32,
#     "end": 53
#   },
#   {
#     "text": "leukemia",
#     "label": "disease",
#     "begin": 126,
#     "end": 134
#   },
#   {
#     "text": "lymphoma",
#     "label": "disease",
#     "begin": 136,
#     "end": 144
#   },
#   {
#     "text": "breast cancer",
#     "label": "disease",
#     "begin": 150,
#     "end": 163
#   }
# ]
# Entities for JSON object on line 250:
# [
#   {
#     "text": "ataxia-telangiectasia",
#     "label": "disease",
#     "begin": 55,
#     "end": 76
#   },
#   {
#     "text": "A-T",
#     "label": "disease",
#     "begin": 78,
#     "end": 81
#   }
# ]
# Entities for JSON object on line 251:
# [
#   {
#     "text": "cerebellar degeneration",
#     "label": "disease",
#     "begin": 176,
#     "end": 199
#   }
# ]
# Entities for JSON object on line 252:
# [
#   {
#     "text": "A-T",
#     "label": "disease",
#     "begin": 18,
#     "end": 21
#   },
#   {
#     "text": "breast cancer",
#     "label": "disease",
#     "begin": 110,
#     "end": 123
#   },
#   {
#     "text": "A-T",
#     "label": "disease",
#     "begin": 226,
#     "end": 229
#   },
#   {
#     "text": "cerebellar degeneration",
#     "label": "disease",
#     "begin": 266,
#     "end": 289
#   }
# ]
# Entities for JSON object on line 253:
# []
# Entities for JSON object on line 254:
# [
#   {
#     "text": "A-T",
#     "label": "disease",
#     "begin": 32,
#     "end": 35
#   },
#   {
#     "text": "leukemia",
#     "label": "disease",
#     "begin": 76,
#     "end": 84
#   },
#   {
#     "text": "lymphoma",
#     "label": "disease",
#     "begin": 86,
#     "end": 94
#   },
#   {
#     "text": "Hodgkin lymphoma",
#     "label": "disease",
#     "begin": 133,
#     "end": 149
#   }
# ]
# Entities for JSON object on line 255:
# []
# Entities for JSON object on line 256:
# [
#   {
#     "text": "A-T",
#     "label": "disease",
#     "begin": 28,
#     "end": 31
#   }
# ]
# Entities for JSON object on line 257:
# [
#   {
#     "text": "myotonic dystrophy",
#     "label": "disease",
#     "begin": 35,
#     "end": 53
#   }
# ]
# Entities for JSON object on line 258:
# [
#   {
#     "text": "myotonic dystrophy",
#     "label": "disease",
#     "begin": 191,
#     "end": 209
#   }
# ]
# Entities for JSON object on line 259:
# []
# Entities for JSON object on line 260:
# []
# Entities for JSON object on line 261:
# []
# Entities for JSON object on line 262:
# []
# Entities for JSON object on line 263:
# []
# Entities for JSON object on line 264:
# [
#   {
#     "text": "hemochromatosis",
#     "label": "disease",
#     "begin": 4,
#     "end": 19
#   }
# ]
# Entities for JSON object on line 265:
# [
#   {
#     "text": "hereditary hemochromatosis",
#     "label": "disease",
#     "begin": 68,
#     "end": 94
#   }
# ]
# Entities for JSON object on line 266:
# []
# Entities for JSON object on line 267:
# []
# Entities for JSON object on line 268:
# []
# Entities for JSON object on line 269:
# []
# Entities for JSON object on line 270:
# []
# Entities for JSON object on line 271:
# []
# Entities for JSON object on line 272:
# []
# Entities for JSON object on line 273:
# []
# Entities for JSON object on line 274:
# []
# Entities for JSON object on line 275:
# []
# Entities for JSON object on line 276:
# [
#   {
#     "text": "hereditary hemochromatosis",
#     "label": "disease",
#     "begin": 219,
#     "end": 245
#   }
# ]
# Entities for JSON object on line 277:
# []
# Entities for JSON object on line 278:
# [
#   {
#     "text": "Angelman syndrome",
#     "label": "disease",
#     "begin": 103,
#     "end": 120
#   },
#   {
#     "text": "uniparental disomy",
#     "label": "disease",
#     "begin": 185,
#     "end": 203
#   }
# ]
# Entities for JSON object on line 279:
# []
# Entities for JSON object on line 280:
# []
# Entities for JSON object on line 281:
# []
# Entities for JSON object on line 282:
# []
# Entities for JSON object on line 283:
# []
# Entities for JSON object on line 284:
# []
# Entities for JSON object on line 285:
# []
# Entities for JSON object on line 286:
# [
#   {
#     "text": "Cowden disease",
#     "label": "disease",
#     "begin": 53,
#     "end": 67
#   },
#   {
#     "text": "Bannayan-Zonana syndrome",
#     "label": "disease",
#     "begin": 72,
#     "end": 96
#   },
#   {
#     "text": "hamartoma syndromes",
#     "label": "disease",
#     "begin": 102,
#     "end": 121
#   }
# ]
# Entities for JSON object on line 287:
# [
#   {
#     "text": "tumour",
#     "label": "disease",
#     "begin": 4,
#     "end": 10
#   }
# ]
# Entities for JSON object on line 288:
# [
#   {
#     "text": "malignancy",
#     "label": "disease",
#     "begin": 149,
#     "end": 159
#   }
# ]
# Entities for JSON object on line 289:
# [
#   {
#     "text": "sporadic breast, brain, prostate and kidney cancer",
#     "label": "disease",
#     "begin": 54,
#     "end": 104
#   },
#   {
#     "text": "tumours",
#     "label": "disease",
#     "begin": 139,
#     "end": 146
#   },
#   {
#     "text": "endometrial carcinomas",
#     "label": "disease",
#     "begin": 155,
#     "end": 177
#   },
#   {
#     "text": "malignant melanoma",
#     "label": "disease",
#     "begin": 179,
#     "end": 197
#   },
#   {
#     "text": "thyroid tumours",
#     "label": "disease",
#     "begin": 202,
#     "end": 217
#   }
# ]
# Entities for JSON object on line 290:
# [
#   {
#     "text": "hamartoma syndromes",
#     "label": "disease",
#     "begin": 68,
#     "end": 87
#   },
#   {
#     "text": "Cowden disease",
#     "label": "disease",
#     "begin": 88,
#     "end": 102
#   },
#   {
#     "text": "CD",
#     "label": "disease",
#     "begin": 104,
#     "end": 106
#   },
#   {
#     "text": "Bannayan-Zonana (BZS) or Ruvalcaba-Riley-Smith syndrome",
#     "label": "disease",
#     "begin": 124,
#     "end": 179
#   }
# ]
# Entities for JSON object on line 291:
# [
#   {
#     "text": "CD",
#     "label": "disease",
#     "begin": 25,
#     "end": 27
#   },
#   {
#     "text": "BZS",
#     "label": "disease",
#     "begin": 47,
#     "end": 50
#   }
# ]
# Entities for JSON object on line 292:
# [
#   {
#     "text": "CD",
#     "label": "disease",
#     "begin": 49,
#     "end": 51
#   }
# ]
# Entities for JSON object on line 293:
# []
# Entities for JSON object on line 294:
# [
#   {
#     "text": "CD",
#     "label": "disease",
#     "begin": 32,
#     "end": 34
#   },
#   {
#     "text": "CD",
#     "label": "disease",
#     "begin": 117,
#     "end": 119
#   }
# ]
# Entities for JSON object on line 295:
# []
# Entities for JSON object on line 296:
# [
#   {
#     "text": "BZS",
#     "label": "disease",
#     "begin": 63,
#     "end": 66
#   }
# ]
# Entities for JSON object on line 297:
# []
# Entities for JSON object on line 298:
# [
#   {
#     "text": "CD",
#     "label": "disease",
#     "begin": 124,
#     "end": 126
#   },
#   {
#     "text": "BZS",
#     "label": "disease",
#     "begin": 144,
#     "end": 147
#   }
# ]
# Entities for JSON object on line 299:
# [
#   {
#     "text": "BZS",
#     "label": "disease",
#     "begin": 69,
#     "end": 72
#   }
# ]
# Entities for JSON object on line 300:
# [
#   {
#     "text": "CD",
#     "label": "disease",
#     "begin": 52,
#     "end": 54
#   }
# ]
# Entities for JSON object on line 301:
# [
#   {
#     "text": "CD",
#     "label": "disease",
#     "begin": 51,
#     "end": 53
#   },
#   {
#     "text": "breast disease",
#     "label": "disease",
#     "begin": 68,
#     "end": 82
#   }
# ]
# Entities for JSON object on line 302:
# []
# Entities for JSON object on line 303:
# [
#   {
#     "text": "malignant breast disease",
#     "label": "disease",
#     "begin": 109,
#     "end": 133
#   }
# ]
# Entities for JSON object on line 304:
# []
# Entities for JSON object on line 305:
# [
#   {
#     "text": "CD",
#     "label": "disease",
#     "begin": 86,
#     "end": 88
#   }
# ]
# Entities for JSON object on line 306:
# [
#   {
#     "text": "complement component C6 deficiency",
#     "label": "disease",
#     "begin": 35,
#     "end": 69
#   }
# ]
# Entities for JSON object on line 307:
# [
#   {
#     "text": "Complement component C6 deficiency",
#     "label": "disease",
#     "begin": 0,
#     "end": 34
#   },
#   {
#     "text": "C6D",
#     "label": "disease",
#     "begin": 36,
#     "end": 39
#   },
#   {
#     "text": "meningococcal meningitis",
#     "label": "disease",
#     "begin": 99,
#     "end": 123
#   }
# ]
# Entities for JSON object on line 308:
# [
#   {
#     "text": "C6D",
#     "label": "disease",
#     "begin": 46,
#     "end": 49
#   },
#   {
#     "text": "meningitis",
#     "label": "disease",
#     "begin": 74,
#     "end": 84
#   },
#   {
#     "text": "neisserial infection",
#     "label": "disease",
#     "begin": 94,
#     "end": 114
#   }
# ]
# Entities for JSON object on line 309:
# []
# Entities for JSON object on line 310:
# [
#   {
#     "text": "C6D",
#     "label": "disease",
#     "begin": 134,
#     "end": 137
#   }
# ]
# Entities for JSON object on line 311:
# []
# Entities for JSON object on line 312:
# []
# Entities for JSON object on line 313:
# []
# Entities for JSON object on line 314:
# [
#   {
#     "text": "aniridia",
#     "label": "disease",
#     "begin": 44,
#     "end": 52
#   },
#   {
#     "text": "Peters anomaly",
#     "label": "disease",
#     "begin": 95,
#     "end": 109
#   },
#   {
#     "text": "congenital cataracts",
#     "label": "disease",
#     "begin": 116,
#     "end": 136
#   },
#   {
#     "text": "autosomal dominant keratitis",
#     "label": "disease",
#     "begin": 143,
#     "end": 171
#   },
#   {
#     "text": "isolated foveal hypoplasia",
#     "label": "disease",
#     "begin": 182,
#     "end": 208
#   }
# ]
# Entities for JSON object on line 315:
# [
#   {
#     "text": "aniridia",
#     "label": "disease",
#     "begin": 60,
#     "end": 68
#   }
# ]
# Entities for JSON object on line 316:
# []
# Entities for JSON object on line 317:
# []
# Entities for JSON object on line 318:
# []
# Entities for JSON object on line 319:
# []
# Entities for JSON object on line 320:
# []
# Entities for JSON object on line 321:
# [
#   {
#     "text": "breast cancer",
#     "label": "disease",
#     "begin": 78,
#     "end": 91
#   }
# ]
# Entities for JSON object on line 322:
# [
#   {
#     "text": "Breast Cancer",
#     "label": "disease",
#     "begin": 4,
#     "end": 17
#   }
# ]
# Entities for JSON object on line 323:
# [
#   {
#     "text": "inherited breast cancer",
#     "label": "disease",
#     "begin": 39,
#     "end": 62
#   },
#   {
#     "text": "breast cancer",
#     "label": "disease",
#     "begin": 159,
#     "end": 172
#   },
#   {
#     "text": "Breast Cancer",
#     "label": "disease",
#     "begin": 191,
#     "end": 204
#   }
# ]
# Entities for JSON object on line 324:
# [
#   {
#     "text": "ovarian or other cancers",
#     "label": "disease",
#     "begin": 59,
#     "end": 83
#   }
# ]
# Entities for JSON object on line 325:
# []
# Entities for JSON object on line 326:
# [
#   {
#     "text": "breast-ovarian cancer",
#     "label": "disease",
#     "begin": 26,
#     "end": 47
#   }
# ]
# Entities for JSON object on line 327:
# [
#   {
#     "text": "male and female breast cancer",
#     "label": "disease",
#     "begin": 42,
#     "end": 71
#   }
# ]
# Entities for JSON object on line 328:
# [
#   {
#     "text": "breast cancer",
#     "label": "disease",
#     "begin": 116,
#     "end": 129
#   }
# ]
# Entities for JSON object on line 329:
# []
# Entities for JSON object on line 330:
# []
# Entities for JSON object on line 331:
# []
# Entities for JSON object on line 332:
# []
# Entities for JSON object on line 333:
# [
#   {
#     "text": "breast cancer",
#     "label": "disease",
#     "begin": 33,
#     "end": 46
#   }
# ]
# Entities for JSON object on line 334:
# [
#   {
#     "text": "ovarian cancer",
#     "label": "disease",
#     "begin": 18,
#     "end": 32
#   }
# ]
# Entities for JSON object on line 335:
# []
# Entities for JSON object on line 336:
# [
#   {
#     "text": "breast cancer",
#     "label": "disease",
#     "begin": 21,
#     "end": 34
#   }
# ]
# Entities for JSON object on line 337:
# [
#   {
#     "text": "Eye movement abnormalities",
#     "label": "disease",
#     "begin": 0,
#     "end": 26
#   },
#   {
#     "text": "cerebellar ataxia type I",
#     "label": "disease",
#     "begin": 73,
#     "end": 97
#   }
# ]
# Entities for JSON object on line 338:
# [
#   {
#     "text": "cerebellar ataxias type I",
#     "label": "disease",
#     "begin": 177,
#     "end": 202
#   },
#   {
#     "text": "spinocerebellar ataxias 1 and 2",
#     "label": "disease",
#     "begin": 203,
#     "end": 234
#   },
#   {
#     "text": "SCA1",
#     "label": "disease",
#     "begin": 236,
#     "end": 240
#   },
#   {
#     "text": "SCA2",
#     "label": "disease",
#     "begin": 248,
#     "end": 252
#   },
#   {
#     "text": "SCA3",
#     "label": "disease",
#     "begin": 264,
#     "end": 268
#   },
#   {
#     "text": "Machado-Joseph disease",
#     "label": "disease",
#     "begin": 269,
#     "end": 291
#   },
#   {
#     "text": "MJD",
#     "label": "disease",
#     "begin": 293,
#     "end": 296
#   }
# ]
# Entities for JSON object on line 339:
# [
#   {
#     "text": "SCA1",
#     "label": "disease",
#     "begin": 3,
#     "end": 7
#   },
#   {
#     "text": "hypermetria",
#     "label": "disease",
#     "begin": 69,
#     "end": 80
#   }
# ]
# Entities for JSON object on line 340:
# []
# Entities for JSON object on line 341:
# [
#   {
#     "text": "SCA2",
#     "label": "disease",
#     "begin": 3,
#     "end": 7
#   }
# ]
# Entities for JSON object on line 342:
# []
# Entities for JSON object on line 343:
# []
# Entities for JSON object on line 344:
# [
#   {
#     "text": "SCA3",
#     "label": "disease",
#     "begin": 3,
#     "end": 7
#   },
#   {
#     "text": "gaze-evoked nystagmus",
#     "label": "disease",
#     "begin": 9,
#     "end": 30
#   }
# ]
# Entities for JSON object on line 345:
# [
#   {
#     "text": "gaze-evoked nystagmus",
#     "label": "disease",
#     "begin": 75,
#     "end": 96
#   },
#   {
#     "text": "SCA1",
#     "label": "disease",
#     "begin": 144,
#     "end": 148
#   },
#   {
#     "text": "SCA2",
#     "label": "disease",
#     "begin": 160,
#     "end": 164
#   },
#   {
#     "text": "SCA3",
#     "label": "disease",
#     "begin": 194,
#     "end": 198
#   },
#   {
#     "text": "SCA1",
#     "label": "disease",
#     "begin": 289,
#     "end": 293
#   },
#   {
#     "text": "SCA2",
#     "label": "disease",
#     "begin": 295,
#     "end": 299
#   },
#   {
#     "text": "SCA3",
#     "label": "disease",
#     "begin": 305,
#     "end": 309
#   }
# ]
# Entities for JSON object on line 346:
# [
#   {
#     "text": "idiopathic ventricular fibrillation",
#     "label": "disease",
#     "begin": 42,
#     "end": 77
#   }
# ]
# Entities for JSON object on line 347:
# [
#   {
#     "text": "Ventricular fibrillation",
#     "label": "disease",
#     "begin": 0,
#     "end": 24
#   }
# ]
# Entities for JSON object on line 348:
# [
#   {
#     "text": "idiopathic ventricular fibrillation",
#     "label": "disease",
#     "begin": 155,
#     "end": 190
#   },
#   {
#     "text": "IVF",
#     "label": "disease",
#     "begin": 192,
#     "end": 195
#   }
# ]
# Entities for JSON object on line 349:
# [
#   {
#     "text": "IVF",
#     "label": "disease",
#     "begin": 20,
#     "end": 23
#   }
# ]
# Entities for JSON object on line 350:
# [
#   {
#     "text": "sudden death",
#     "label": "disease",
#     "begin": 70,
#     "end": 82
#   },
#   {
#     "text": "IVF",
#     "label": "disease",
#     "begin": 122,
#     "end": 125
#   }
# ]
# Entities for JSON object on line 351:
# [
#   {
#     "text": "IVF",
#     "label": "disease",
#     "begin": 8,
#     "end": 11
#   }
# ]
# Entities for JSON object on line 352:
# [
#   {
#     "text": "IVF",
#     "label": "disease",
#     "begin": 134,
#     "end": 137
#   }
# ]
# Entities for JSON object on line 353:
# []
# Entities for JSON object on line 354:
# [
#   {
#     "text": "IVF",
#     "label": "disease",
#     "begin": 102,
#     "end": 105
#   }
# ]
# Entities for JSON object on line 355:
# [
#   {
#     "text": "mucopolysaccharidosis IVA",
#     "label": "disease",
#     "begin": 27,
#     "end": 52
#   }
# ]
# Entities for JSON object on line 356:
# [
#   {
#     "text": "Mucopolysaccharidosis IVA",
#     "label": "disease",
#     "begin": 0,
#     "end": 25
#   },
#   {
#     "text": "MPS IVA",
#     "label": "disease",
#     "begin": 27,
#     "end": 34
#   },
#   {
#     "text": "autosomal recessive lysosomal storage disorder",
#     "label": "disease",
#     "begin": 42,
#     "end": 88
#   },
#   {
#     "text": "genetic defect",
#     "label": "disease",
#     "begin": 101,
#     "end": 115
#   }
# ]
# Entities for JSON object on line 357:
# [
#   {
#     "text": "MPS IVA",
#     "label": "disease",
#     "begin": 133,
#     "end": 140
#   }
# ]
# Entities for JSON object on line 358:
# [
#   {
#     "text": "MPS IVA",
#     "label": "disease",
#     "begin": 58,
#     "end": 65
#   }
# ]
# Entities for JSON object on line 359:
# []
# Entities for JSON object on line 360:
# []
# Entities for JSON object on line 361:
# []
# Entities for JSON object on line 362:
# []
# Entities for JSON object on line 363:
# []
# Entities for JSON object on line 364:
# []
# Entities for JSON object on line 365:
# []
# Entities for JSON object on line 366:
# []
# Entities for JSON object on line 367:
# [
# ...
#     "label": "disease",
#     "begin": 75,
#     "end": 104
#   },
#   {
#     "text": "colorectal cancer",
#     "label": "disease",
#     "begin": 171,
#     "end": 188
#   }
# ]
# Entities for JSON object on line 839:
# [
#   {
#     "text": "hereditary coproporphyria",
#     "label": "disease",
#     "begin": 66,
#     "end": 91
#   }
# ]
# Entities for JSON object on line 840:
# [
#   {
#     "text": "Hereditary coproporphyria",
#     "label": "disease",
#     "begin": 0,
#     "end": 25
#   },
#   {
#     "text": "HC",
#     "label": "disease",
#     "begin": 27,
#     "end": 29
#   },
#   {
#     "text": "hepatic porphyria",
#     "label": "disease",
#     "begin": 43,
#     "end": 60
#   },
#   {
#     "text": "deficient activity of coproporphyrinogen III oxidase",
#     "label": "disease",
#     "begin": 107,
#     "end": 159
#   }
# ]
# Entities for JSON object on line 841:
# [
#   {
#     "text": "neurological dysfunction",
#     "label": "disease",
#     "begin": 77,
#     "end": 101
#   },
#   {
#     "text": "infectious diseases",
#     "label": "disease",
#     "begin": 170,
#     "end": 189
#   }
# ]
# Entities for JSON object on line 842:
# []
# Entities for JSON object on line 843:
# [
#   {
#     "text": "HC",
#     "label": "disease",
#     "begin": 259,
#     "end": 261
#   }
# ]
# Entities for JSON object on line 844:
# []
# Entities for JSON object on line 845:
# []
# Entities for JSON object on line 846:
# []
# Entities for JSON object on line 847:
# []
# Entities for JSON object on line 848:
# []
# Entities for JSON object on line 849:
# [
#   {
#     "text": "HC",
#     "label": "disease",
#     "begin": 103,
#     "end": 105
#   },
#   {
#     "text": "gene defects",
#     "label": "disease",
#     "begin": 188,
#     "end": 200
#   }
# ]
# Entities for JSON object on line 850:
# [
#   {
#     "text": "metachromatic leukodystrophy",
#     "label": "disease",
#     "begin": 95,
#     "end": 123
#   }
# ]
# Entities for JSON object on line 851:
# [
#   {
#     "text": "metachromatic leukodystrophy",
#     "label": "disease",
#     "begin": 72,
#     "end": 100
#   },
#   {
#     "text": "MLD",
#     "label": "disease",
#     "begin": 102,
#     "end": 105
#   }
# ]
# Entities for JSON object on line 852:
# [
#   {
#     "text": "MLD",
#     "label": "disease",
#     "begin": 178,
#     "end": 181
#   }
# ]
# Entities for JSON object on line 853:
# []
# Entities for JSON object on line 854:
# []
# Entities for JSON object on line 855:
# []
# Entities for JSON object on line 856:
# []
# Entities for JSON object on line 857:
# [
#   {
#     "text": "MLD",
#     "label": "disease",
#     "begin": 45,
#     "end": 48
#   }
# ]
# Entities for JSON object on line 858:
# [
#   {
#     "text": "MLD",
#     "label": "disease",
#     "begin": 121,
#     "end": 124
#   }
# ]
# Entities for JSON object on line 859:
# [
#   {
#     "text": "MLD",
#     "label": "disease",
#     "begin": 59,
#     "end": 62
#   }
# ]
# Entities for JSON object on line 860:
# []
# Entities for JSON object on line 861:
# [
#   {
#     "text": "hematological malignancy",
#     "label": "disease",
#     "begin": 37,
#     "end": 61
#   },
#   {
#     "text": "neurofibromatosis type 1",
#     "label": "disease",
#     "begin": 66,
#     "end": 90
#   }
# ]
# Entities for JSON object on line 862:
# [
#   {
#     "text": "hereditary nonpolyposis colorectal cancer",
#     "label": "disease",
#     "begin": 74,
#     "end": 115
#   }
# ]
# Entities for JSON object on line 863:
# []
# Entities for JSON object on line 864:
# [
#   {
#     "text": "hereditary nonpolyposis colorectal cancer",
#     "label": "disease",
#     "begin": 40,
#     "end": 81
#   },
#   {
#     "text": "hematological malignancy",
#     "label": "disease",
#     "begin": 103,
#     "end": 127
#   },
#   {
#     "text": "neurofibromatosis type 1",
#     "label": "disease",
#     "begin": 193,
#     "end": 217
#   },
#   {
#     "text": "NF1",
#     "label": "disease",
#     "begin": 219,
#     "end": 222
#   }
# ]
# Entities for JSON object on line 865:
# []
# Entities for JSON object on line 866:
# [
#   {
#     "text": "leukemia",
#     "label": "disease",
#     "begin": 133,
#     "end": 141
#   },
#   {
#     "text": "lymphoma",
#     "label": "disease",
#     "begin": 149,
#     "end": 157
#   },
#   {
#     "text": "neurofibromatosis type 1",
#     "label": "disease",
#     "begin": 174,
#     "end": 198
#   }
# ]
# Entities for JSON object on line 867:
# [
#   {
#     "text": "congenital eye malformations",
#     "label": "disease",
#     "begin": 103,
#     "end": 131
#   }
# ]
# Entities for JSON object on line 868:
# [
#   {
#     "text": "aniridia",
#     "label": "disease",
#     "begin": 42,
#     "end": 50
#   },
#   {
#     "text": "congenital absence of the iris",
#     "label": "disease",
#     "begin": 52,
#     "end": 82
#   },
#   {
#     "text": "malformation of the eye",
#     "label": "disease",
#     "begin": 101,
#     "end": 124
#   }
# ]
# Entities for JSON object on line 869:
# [
#   {
#     "text": "aniridia",
#     "label": "disease",
#     "begin": 34,
#     "end": 42
#   }
# ]
# Entities for JSON object on line 870:
# [
#   {
#     "text": "aniridia",
#     "label": "disease",
#     "begin": 207,
#     "end": 215
#   }
# ]
# Entities for JSON object on line 871:
# [
#   {
#     "text": "aniridia",
#     "label": "disease",
#     "begin": 215,
#     "end": 223
#   }
# ]
# Entities for JSON object on line 872:
# [
#   {
#     "text": "ectopia pupillae",
#     "label": "disease",
#     "begin": 96,
#     "end": 112
#   },
#   {
#     "text": "displaced pupils",
#     "label": "disease",
#     "begin": 114,
#     "end": 130
#   },
#   {
#     "text": "congenital nystagmus",
#     "label": "disease",
#     "begin": 136,
#     "end": 156
#   },
#   {
#     "text": "searching gaze",
#     "label": "disease",
#     "begin": 158,
#     "end": 172
#   },
#   {
#     "text": "aniridia",
#     "label": "disease",
#     "begin": 221,
#     "end": 229
#   }
# ]
# Entities for JSON object on line 873:
# []
# Entities for JSON object on line 874:
# [
#   {
#     "text": "PAX6-related disease",
#     "label": "disease",
#     "begin": 160,
#     "end": 180
#   }
# ]
# Entities for JSON object on line 875:
# [
#   {
#     "text": "deficiency of the second component of complement",
#     "label": "disease",
#     "begin": 105,
#     "end": 153
#   }
# ]
# Entities for JSON object on line 876:
# [
#   {
#     "text": "deficiency of the second component of complement",
#     "label": "disease",
#     "begin": 102,
#     "end": 150
#   }
# ]
# Entities for JSON object on line 877:
# [
#   {
#     "text": "C2 deficiency",
#     "label": "disease",
#     "begin": 72,
#     "end": 85
#   }
# ]
# Entities for JSON object on line 878:
# [
#   {
#     "text": "C2 deficiency",
#     "label": "disease",
#     "begin": 44,
#     "end": 57
#   }
# ]
# Entities for JSON object on line 879:
# [
#   {
#     "text": "C2 deficiency",
#     "label": "disease",
#     "begin": 65,
#     "end": 78
#   }
# ]
# Entities for JSON object on line 880:
# []
# Entities for JSON object on line 881:
# [
#   {
#     "text": "C2 deficiency",
#     "label": "disease",
#     "begin": 53,
#     "end": 66
#   }
# ]
# Entities for JSON object on line 882:
# []
# Entities for JSON object on line 883:
# []
# Entities for JSON object on line 884:
# []
# Entities for JSON object on line 885:
# []
# Entities for JSON object on line 886:
# []
# Entities for JSON object on line 887:
# []
# Entities for JSON object on line 888:
# []
# Entities for JSON object on line 889:
# [
#   {
#     "text": "C2 deficiency",
#     "label": "disease",
#     "begin": 54,
#     "end": 67
#   },
#   {
#     "text": "C2 deficiency",
#     "label": "disease",
#     "begin": 163,
#     "end": 176
#   },
#   {
#     "text": "C2 deficiency",
#     "label": "disease",
#     "begin": 204,
#     "end": 217
#   },
#   {
#     "text": "C2 deficiency",
#     "label": "disease",
#     "begin": 381,
#     "end": 394
#   }
# ]
# Entities for JSON object on line 890:
# [
#   {
#     "text": "Emery-Dreifuss muscular dystrophy",
#     "label": "disease",
#     "begin": 68,
#     "end": 101
#   }
# ]
# Entities for JSON object on line 891:
# [
#   {
#     "text": "Emery-Dreifuss muscular dystrophy",
#     "label": "disease",
#     "begin": 70,
#     "end": 103
#   },
#   {
#     "text": "EDMD",
#     "label": "disease",
#     "begin": 105,
#     "end": 109
#   }
# ]
# Entities for JSON object on line 892:
# []
# Entities for JSON object on line 893:
# []
# Entities for JSON object on line 894:
# []
# Entities for JSON object on line 895:
# []
# Entities for JSON object on line 896:
# [
#   {
#     "text": "cardiac defects",
#     "label": "disease",
#     "begin": 174,
#     "end": 189
#   },
#   {
#     "text": "EDMD",
#     "label": "disease",
#     "begin": 193,
#     "end": 197
#   }
# ]
# Entities for JSON object on line 897:
# []
# Entities for JSON object on line 898:
# [
#   {
#     "text": "EDMD",
#     "label": "disease",
#     "begin": 102,
#     "end": 106
#   }
# ]
# Entities for JSON object on line 899:
# []
# Entities for JSON object on line 900:
# []
# Entities for JSON object on line 901:
# [
#   {
#     "text": "EDMD",
#     "label": "disease",
#     "begin": 3,
#     "end": 7
#   }
# ]
# Entities for JSON object on line 902:
# [
#   {
#     "text": "copper toxicosis",
#     "label": "disease",
#     "begin": 23,
#     "end": 39
#   }
# ]
# Entities for JSON object on line 903:
# [
#   {
#     "text": "hepatic copper accumulation",
#     "label": "disease",
#     "begin": 9,
#     "end": 36
#   },
#   {
#     "text": "inherited disorder",
#     "label": "disease",
#     "begin": 57,
#     "end": 75
#   }
# ]
# Entities for JSON object on line 904:
# [
#   {
#     "text": "hepatic copper accumulation",
#     "label": "disease",
#     "begin": 19,
#     "end": 46
#   },
#   {
#     "text": "Wilson disease",
#     "label": "disease",
#     "begin": 93,
#     "end": 107
#   },
#   {
#     "text": "WD",
#     "label": "disease",
#     "begin": 109,
#     "end": 111
#   }
# ]
# Entities for JSON object on line 905:
# []
# Entities for JSON object on line 906:
# [
#   {
#     "text": "copper overload",
#     "label": "disease",
#     "begin": 57,
#     "end": 72
#   },
#   {
#     "text": "non-Indian childhood cirrhosis",
#     "label": "disease",
#     "begin": 81,
#     "end": 111
#   }
# ]
# Entities for JSON object on line 907:
# [
#   {
#     "text": "copper toxicosis",
#     "label": "disease",
#     "begin": 48,
#     "end": 64
#   },
#   {
#     "text": "CT",
#     "label": "disease",
#     "begin": 66,
#     "end": 68
#   },
#   {
#     "text": "liver disease",
#     "label": "disease",
#     "begin": 149,
#     "end": 162
#   }
# ]
# Entities for JSON object on line 908:
# [
#   {
#     "text": "WD",
#     "label": "disease",
#     "begin": 24,
#     "end": 26
#   },
#   {
#     "text": "CT",
#     "label": "disease",
#     "begin": 61,
#     "end": 63
#   }
# ]
# Entities for JSON object on line 909:
# [
#   {
#     "text": "CT",
#     "label": "disease",
#     "begin": 63,
#     "end": 65
#   }
# ]
# Entities for JSON object on line 910:
# [
#   {
#     "text": "WD",
#     "label": "disease",
#     "begin": 144,
#     "end": 146
#   },
#   {
#     "text": "CT",
#     "label": "disease",
#     "begin": 171,
#     "end": 173
#   }
# ]
# Entities for JSON object on line 911:
# [
#   {
#     "text": "CT",
#     "label": "disease",
#     "begin": 27,
#     "end": 29
#   }
# ]
# Entities for JSON object on line 912:
# []
# Entities for JSON object on line 913:
# []
# Entities for JSON object on line 914:
# []
# Entities for JSON object on line 915:
# [
#   {
#     "text": "APC",
#     "label": "disease",
#     "begin": 26,
#     "end": 29
#   },
#   {
#     "text": "FAP",
#     "label": "disease",
#     "begin": 96,
#     "end": 99
#   },
#   {
#     "text": "APC",
#     "label": "disease",
#     "begin": 129,
#     "end": 132
#   },
#   {
#     "text": "colorectal cancer",
#     "label": "disease",
#     "begin": 155,
#     "end": 172
#   }
# ]
# Entities for JSON object on line 916:
# [
#   {
#     "text": "colorectal cancer",
#     "label": "disease",
#     "begin": 35,
#     "end": 52
#   },
#   {
#     "text": "familial adenomatous polyposis",
#     "label": "disease",
#     "begin": 108,
#     "end": 138
#   },
#   {
#     "text": "FAP",
#     "label": "disease",
#     "begin": 140,
#     "end": 143
#   },
#   {
#     "text": "adenomatous polyposis coli",
#     "label": "disease",
#     "begin": 190,
#     "end": 216
#   },
#   {
#     "text": "APC",
#     "label": "disease",
#     "begin": 218,
#     "end": 221
#   }
# ]
# Entities for JSON object on line 917:
# [
#   {
#     "text": "APC",
#     "label": "disease",
#     "begin": 47,
#     "end": 50
#   },
#   {
#     "text": "APC",
#     "label": "disease",
#     "begin": 188,
#     "end": 191
#   },
#   {
#     "text": "colorectal cancer",
#     "label": "disease",
#     "begin": 213,
#     "end": 230
#   }
# ]
# Entities for JSON object on line 918:
# [
#   {
#     "text": "APC",
#     "label": "disease",
#     "begin": 12,
#     "end": 15
#   },
#   {
#     "text": "FAP",
#     "label": "disease",
#     "begin": 51,
#     "end": 54
#   },
#   {
#     "text": "colorectal cancer",
#     "label": "disease",
#     "begin": 70,
#     "end": 87
#   }
# ]
# Entities for JSON object on line 919:
# [
#   {
#     "text": "FAP",
#     "label": "disease",
#     "begin": 84,
#     "end": 87
#   }
# ]
# Entities for JSON object on line 920:
# [
#   {
#     "text": "colorectal cancer",
#     "label": "disease",
#     "begin": 100,
#     "end": 117
#   }
# ]
# Entities for JSON object on line 921:
# [
#   {
#     "text": "FAP",
#     "label": "disease",
#     "begin": 123,
#     "end": 126
#   }
# ]
# Entities for JSON object on line 922:
# []
# Entities for JSON object on line 923:
# [
#   {
#     "text": "FAP",
#     "label": "disease",
#     "begin": 112,
#     "end": 115
#   },
#   {
#     "text": "colorectal cancer",
#     "label": "disease",
#     "begin": 128,
#     "end": 145
#   }
# ]
# Entities for JSON object on line 924:
# [
#   {
#     "text": "Inherited colorectal polyposis",
#     "label": "disease",
#     "begin": 0,
#     "end": 30
#   },
#   {
#     "text": "cancer",
#     "label": "disease",
#     "begin": 35,
#     "end": 41
#   }
# ]
# Entities for JSON object on line 925:
# [
#   {
#     "text": "APC",
#     "label": "disease",
#     "begin": 50,
#     "end": 53
#   },
#   {
#     "text": "colorectal tumor",
#     "label": "disease",
#     "begin": 83,
#     "end": 99
#   },
#   {
#     "text": "familial adenomatous polyposis syndrome",
#     "label": "disease",
#     "begin": 113,
#     "end": 152
#   }
# ]
# Entities for JSON object on line 926:
# [
#   {
#     "text": "APC",
#     "label": "disease",
#     "begin": 77,
#     "end": 80
#   }
# ]
# Entities for JSON object on line 927:
# [
#   {
#     "text": "APC",
#     "label": "disease",
#     "begin": 34,
#     "end": 37
#   },
#   {
#     "text": "adenomatous polyps",
#     "label": "disease",
#     "begin": 161,
#     "end": 179
#   },
#   {
#     "text": "colorectal cancer,",
#     "label": "disease",
#     "begin": 188,
#     "end": 206
#   }
# ]
# Entities for JSON object on line 928:
# []
# Entities for JSON object on line 929:
# []
# Entities for JSON object on line 930:
# []
# Entities for JSON object on line 931:
# [
#   {
#     "text": "colorectal neoplasia",
#     "label": "disease",
#     "begin": 6,
#     "end": 26
#   }
# ]
# Entities for JSON object on line 932:
# [
#   {
#     "text": "adenomas",
#     "label": "disease",
#     "begin": 85,
#     "end": 93
#   },
#   {
#     "text": "colorectal cancers",
#     "label": "disease",
#     "begin": 98,
#     "end": 116
#   }
# ]
# Entities for JSON object on line 933:
# [
#   {
#     "text": "adenoma",
#     "label": "disease",
#     "begin": 59,
#     "end": 66
#   },
#   {
#     "text": "colorectal cancer",
#     "label": "disease",
#     "begin": 134,
#     "end": 151
#   }
# ]
# Entities for JSON object on line 934:
# [
#   {
#     "text": "colorectal cancer",
#     "label": "disease",
#     "begin": 232,
#     "end": 249
#   }
# ]
# Entities for JSON object on line 935:
# [
#   {
#     "text": "non-inherited breast carcinomas",
#     "label": "disease",
#     "begin": 56,
#     "end": 87
#   }
# ]
# Entities for JSON object on line 936:
# [
#   {
#     "text": "tumour",
#     "label": "disease",
#     "begin": 36,
#     "end": 42
#   },
#   {
#     "text": "hereditary breast and ovarian cancer",
#     "label": "disease",
#     "begin": 63,
#     "end": 99
#   },
#   {
#     "text": "non-familial cancers",
#     "label": "disease",
#     "begin": 146,
#     "end": 166
#   }
# ]
# Entities for JSON object on line 937:
# [
#   {
#     "text": "sporadic cancers",
#     "label": "disease",
#     "begin": 28,
#     "end": 44
#   },
#   {
#     "text": "non-familial breast and ovarian cancers",
#     "label": "disease",
#     "begin": 169,
#     "end": 208
#   }
# ]
# Entities for JSON object on line 938:
# []
# Entities for JSON object on line 939:
# []
# Entities for JSON object on line 940:
# [
#   {
#     "text": "breast malignancies",
#     "label": "disease",
#     "begin": 133,
#     "end": 152
#   }
# ]
# Entities for JSON object on line 941:
# [
#   {
#     "text": "invasive lobular cancers",
#     "label": "disease",
#     "begin": 106,
#     "end": 130
#   },
#   {
#     "text": "low-grade ductal carcinomas",
#     "label": "disease",
#     "begin": 135,
#     "end": 162
#   }
# ]
# Entities for JSON object on line 942:
# [
#   {
#     "text": "ductal carcinomas",
#     "label": "disease",
#     "begin": 88,
#     "end": 105
#   },
#   {
#     "text": "sporadic breast cancers",
#     "label": "disease",
#     "begin": 206,
#     "end": 229
#   }
# ]

# %%
import os

# Utility function to process a BIO file and write its contents as JSONL.
def process_bio_file_to_jsonl(input_file, output_file, entity_label, limit=None):
    sentences_token_tags = parse_bio_file(input_file)
    if limit is not None:
        sentences_token_tags = sentences_token_tags[:limit]
    with open(output_file, 'w', encoding='utf-8') as out_f:
        for token_tag_pairs in sentences_token_tags:
            sentence_text, entities = process_sentence(token_tag_pairs, entity_label)
            json_obj = create_json_object(sentence_text, entities)
            out_f.write(json.dumps(json_obj) + "\n")

datasets = {
  "cell_line": {
    "path": "./NERdata/JNLPBA-cl/"
  },
  "cell_type": {
    "path": "./NERdata/JNLPBA-ct/"
  },
  "disease": {
    "path": "./NERdata/NCBI-disease/"
  },
  "dna": {
    "path": "./NERdata/JNLPBA-dna/"
  },
  "rna": {
    "path": "./NERdata/JNLPBA-rna"
  },
  "drug_chemical": {
    "path": "./NERdata/BC4CHEMD/"
  },
  "gene_protein": {
    "path": "./NERdata/BC2GM/"
  },
  "species": {
    "path": "./NERdata/linnaeus/"
  }
}

# Process each dataset
for entity_type, info in datasets.items():
    root_path = info["path"]
    train_file = os.path.join(root_path, "train.txt")
    test_file = os.path.join(root_path, "test.txt")

    # Define output file names
    train_output =  os.path.join(root_path, f"train_{entity_type}.jsonl")
    test_output =  os.path.join(root_path, f"test_{entity_type}.jsonl")
    test256_output =  os.path.join(root_path, f"test256_{entity_type}.jsonl")

    print(f"Processing dataset for entity type: {entity_type}")

    # Process train file
    if os.path.exists(train_file):
        process_bio_file_to_jsonl(train_file, train_output, entity_type)
        print(f"  Written {train_output}")
    else:
        print(f"  Train file not found: {train_file}")

    # Process test file
    if os.path.exists(test_file):
        process_bio_file_to_jsonl(test_file, test_output, entity_type)
        print(f"  Written {test_output}")
        # Process test file with a limit of 256 instances for test256 file
        process_bio_file_to_jsonl(test_file, test256_output, entity_type, limit=256)
        print(f"  Written {test256_output}")
    else:
        print(f"  Test file not found: {test_file}")
# Out:
# Processing dataset for entity type: cell_line
#   Written ./NERdata/JNLPBA-cl/train_cell_line.jsonl
#   Written ./NERdata/JNLPBA-cl/test_cell_line.jsonl
#   Written ./NERdata/JNLPBA-cl/test256_cell_line.jsonl
# Processing dataset for entity type: cell_type
#   Written ./NERdata/JNLPBA-ct/train_cell_type.jsonl
#   Written ./NERdata/JNLPBA-ct/test_cell_type.jsonl
#   Written ./NERdata/JNLPBA-ct/test256_cell_type.jsonl
# Processing dataset for entity type: disease
#   Written ./NERdata/NCBI-disease/train_disease.jsonl
#   Written ./NERdata/NCBI-disease/test_disease.jsonl
#   Written ./NERdata/NCBI-disease/test256_disease.jsonl
# Processing dataset for entity type: dna
#   Written ./NERdata/JNLPBA-dna/train_dna.jsonl
#   Written ./NERdata/JNLPBA-dna/test_dna.jsonl
#   Written ./NERdata/JNLPBA-dna/test256_dna.jsonl
# Processing dataset for entity type: rna
#   Written ./NERdata/JNLPBA-rna/train_rna.jsonl
#   Written ./NERdata/JNLPBA-rna/test_rna.jsonl
#   Written ./NERdata/JNLPBA-rna/test256_rna.jsonl
# Processing dataset for entity type: drug_chemical
#   Written ./NERdata/BC4CHEMD/train_drug_chemical.jsonl
#   Written ./NERdata/BC4CHEMD/test_drug_chemical.jsonl
#   Written ./NERdata/BC4CHEMD/test256_drug_chemical.jsonl
# Processing dataset for entity type: gene_protein
#   Written ./NERdata/BC2GM/train_gene_protein.jsonl
#   Written ./NERdata/BC2GM/test_gene_protein.jsonl
#   Written ./NERdata/BC2GM/test256_gene_protein.jsonl
# Processing dataset for entity type: species
#   Written ./NERdata/linnaeus/train_species.jsonl
#   Written ./NERdata/linnaeus/test_species.jsonl
#   Written ./NERdata/linnaeus/test256_species.jsonl

# %%
def combine_files(file_prefix, output_filename):
    combined_lines = []
    for entity_type, info in datasets.items():
        file_path = os.path.join(info["path"], f"{file_prefix}_{entity_type}.jsonl")
        if os.path.exists(file_path):
            print(f"Reading: {file_path}")
            with open(file_path, 'r', encoding='utf-8') as f:
                combined_lines.extend(f.readlines())
        else:
            print(f"Warning: File not found: {file_path}")

    with open(output_filename, 'w', encoding='utf-8') as out_f:
        out_f.writelines(combined_lines)
    print(f"Combined file written: {output_filename}")

def main():
    # Combine train files into one file
    combine_files("train", "./NERdata/train_combined_NERdata.jsonl")
    # Combine test files into one file
    combine_files("test", "./NERdata/test_combined_NERdata.jsonl")

if __name__ == "__main__":
    main()
# Out:
# Reading: ./NERdata/JNLPBA-cl/train_cell_line.jsonl
# Reading: ./NERdata/JNLPBA-ct/train_cell_type.jsonl
# Reading: ./NERdata/NCBI-disease/train_disease.jsonl
# Reading: ./NERdata/JNLPBA-dna/train_dna.jsonl
# Reading: ./NERdata/JNLPBA-rna/train_rna.jsonl
# Reading: ./NERdata/BC4CHEMD/train_drug_chemical.jsonl
# Reading: ./NERdata/BC2GM/train_gene_protein.jsonl
# Reading: ./NERdata/linnaeus/train_species.jsonl
# Combined file written: ./NERdata/train_combined_NERdata.jsonl
# Reading: ./NERdata/JNLPBA-cl/test_cell_line.jsonl
# Reading: ./NERdata/JNLPBA-ct/test_cell_type.jsonl
# Reading: ./NERdata/NCBI-disease/test_disease.jsonl
# Reading: ./NERdata/JNLPBA-dna/test_dna.jsonl
# Reading: ./NERdata/JNLPBA-rna/test_rna.jsonl
# Reading: ./NERdata/BC4CHEMD/test_drug_chemical.jsonl
# Reading: ./NERdata/BC2GM/test_gene_protein.jsonl
# Reading: ./NERdata/linnaeus/test_species.jsonl
# Combined file written: ./NERdata/test_combined_NERdata.jsonl

# %%
import os
import random

def sample_test_files(output_filename, total_samples=256):
    # Calculate how many samples per entity type.
    num_entity_types = len(datasets)
    samples_per_entity = total_samples // num_entity_types
    combined_samples = []

    for entity_type, info in datasets.items():
        test_file = os.path.join(info['path'], f'test_{entity_type}.jsonl')
        if not os.path.exists(test_file):
            print(f'Warning: File {test_file} not found.')
            continue

        # Read all JSON objects (one per line) from the file.
        with open(test_file, 'r', encoding='utf-8') as f:
            lines = f.readlines()

        # If the file has fewer lines than required, take all; otherwise, sample without replacement.
        if len(lines) < samples_per_entity:
            print(f'Warning: {test_file} has only {len(lines)} lines; using all of them.')
            sampled = lines
        else:
            sampled = random.sample(lines, samples_per_entity)

        combined_samples.extend(sampled)
        print(f'Sampled {len(sampled)} objects from {test_file}')

    # Optionally, you can shuffle the combined samples to mix entities.
    random.shuffle(combined_samples)

    # Write the combined samples to the output file.
    with open(output_filename, 'w', encoding='utf-8') as out_f:
        out_f.writelines(combined_samples)
    print(f'Combined file written: {output_filename}')

if __name__ == '__main__':
    sample_test_files('./NERdata/test256_combined_NERdata.jsonl', total_samples=256)
# Out:
# Sampled 32 objects from ./NERdata/JNLPBA-cl/test_cell_line.jsonl
# Sampled 32 objects from ./NERdata/JNLPBA-ct/test_cell_type.jsonl
# Sampled 32 objects from ./NERdata/NCBI-disease/test_disease.jsonl
# Sampled 32 objects from ./NERdata/JNLPBA-dna/test_dna.jsonl
# Sampled 32 objects from ./NERdata/JNLPBA-rna/test_rna.jsonl
# Sampled 32 objects from ./NERdata/BC4CHEMD/test_drug_chemical.jsonl
# Sampled 32 objects from ./NERdata/BC2GM/test_gene_protein.jsonl
# Sampled 32 objects from ./NERdata/linnaeus/test_species.jsonl
# Combined file written: ./NERdata/test256_combined_NERdata.jsonl

# %% [markdown]
# # [Dataset format](https://cloud.google.com/vertex-ai/generative-ai/docs/models/tune_gemini/tune-gemini-learn#dataset_format)
#
#
# ```jsonl
# {
#   "systemInstruction": {
#     "parts": [
#       {
#         "text": "(see prompt cell)"
#       }
#     ]
#   },
#   "contents": [
#     {
#       "parts": [
#         {
#           "text": "In this study, we investigated the effects of aspirin on human platelet function, as well as its interactions with the TP53 gene in Homo sapiens cells in cell lines such as NCI-H1975."
#         }
#       ]
#     },
#     {
#       "parts": [
#         {
#           "text": "[\n  {\n    \"text\": \"aspirin\",\n    \"label\": \"drug_chemical\",\n    \"begin\": 46,\n    \"end\": 53\n  },\n  {\n    \"text\": \"human\",\n    \"label\": \"species\",\n    \"begin\": 57,\n    \"end\": 62\n  },\n  {\n    \"text\": \"platelet\",\n    \"label\": \"cell_type\",\n    \"begin\": 63,\n    \"end\": 71\n  },\n  {\n    \"text\": \"TP53\",\n    \"label\": \"gene_protein\",\n    \"begin\": 119,\n    \"end\": 123\n  },\n  {\n    \"text\": \"Homo sapiens\",\n    \"label\": \"species\",\n    \"begin\": 132,\n    \"end\": 144\n  },\n  {\n    \"text\": \"NCI-H1975\",\n    \"type\": \"cell_line\",\n    \"begin\": 173,\n    \"end\": 183\n  }\n]"
#         }
#       ]
#     },
#   ]
# }

# %% [markdown]
# # Prompts
# You are a highly specialized biomedical Named Entity Recognition (NER) model. Your task is to accurately identify and extract mentions of biomedical entities from text.
#
# Your goal is to identify and classify entities into one of the following eight types:
#
# - cell_line
# - cell_type
# - disease
# - dna
# - rna
# - drug_chemical
# - gene_protein
# - species
#
# For each identified entity, you must output a JSON object containing the following keys:
#
# - "entity": The extracted entity text.
# - "type": The entity type from the list above.
# - "begin": The starting character index of the entity in the input text (0-indexed).
# - "end": The ending character index of the entity in the input text (exclusive, i.e., the index of the character immediately following the entity).
#
# Your output should be a JSON list of these objects, where each object represents a single entity extracted from the input text. If no entities are found, return an empty JSON list.
#
# If no entities are found in the text, return an empty list as follows:
# ```json
# {"entities": []}
#
# Your output must be in a valid JSON format with the following structure:
# ```json
# {
#   "entities": [
#     {
#       "entity": "extracted_entity_text",
#       "type": "entity_type",
#       "begin": start_index,
#       "end": end_index
#     },
#     ...
#   ]
# }
#
# Do not include any additional commentary or text in your output. Ensure that the JSON is well-formed and follows exactly the format specified above.
#
# Example:
#
# Input Text:
# "In this study, we investigated the effects of aspirin on human platelet function, as well as its interactions with the TP53 gene in Homo sapiens cells in cell lines such as NCI-H1975."
#
# Output JSON:
# ```json
# [
#   {
#     "text": "aspirin",
#     "label": "drug_chemical",
#     "begin": 46,
#     "end": 53
#   },
#   {
#     "text": "human",
#     "label": "species",
#     "begin": 57,
#     "end": 62
#   },
#   {
#     "text": "platelet",
#     "label": "cell_type",
#     "begin": 63,
#     "end": 71
#   },
#   {
#     "text": "TP53",
#     "label": "gene_protein",
#     "begin": 119,
#     "end": 123
#   },
#   {
#     "text": "Homo sapiens",
#     "label": "species",
#     "begin": 132,
#     "end": 144
#   },
#   {
#     "text": "NCI-H1975",
#     "type": "cell_line",
#     "begin": 173,
#     "end": 183
#   }
# ]

# %% [markdown]
# # [Create a tuning job](https://cloud.google.com/vertex-ai/generative-ai/docs/models/gemini-use-supervised-tuning#create_a_text_model_supervised_tuning_job)
#
#  - [Gemini API: Tuning Quickstart with Python](https://github.com/google-gemini/cookbook/blob/main/quickstarts/Tuning.ipynb)
#
# [Supervised Fine Tuning for Gemini: A best practices guide](https://cloud.google.com/blog/products/ai-machine-learning/master-gemini-sft)
#
# Gemini 1.5 Flash
#
# Text fine-tuning: with a dataset size of <1000 examples and average context length <500, we recommend setting epochs = default, learning rate multiplier = 10 and adapter size = 4. With a dataset size >= 1000 examples or average context length >= 500, we recommend epochs = default, learning rate multiplier = default and adapter size = 8.
#
# Gemini 1.5 Pro
#
# Text fine-tuning: with a dataset size of <1000 examples and average context length <500, we recommend setting epochs = 20, learning rate multiplier = 10, adapter size = 4. With a dataset size >= 1000 examples or average context length >= 500, we recommend epochs = 10, learning rate multiplier = default or 5, adapter size = 4.

# %% [markdown]
# - https://anaconda.org/conda-forge/google-generativeai

# %%
from google import genai
from google.genai import types

PROJECT_ID = ""
LOCATION = "us-east4"

client = genai.Client(vertexai=True, project=PROJECT_ID, location=LOCATION)

# list base models
for model_info in client.models.list():
    print(model_info.name)
# list tuned models
for model in client.models.list(config={'page_size': 10, 'query_base': False}):
    print(model)

# %%
# !gsutil cp ./train_combined_NERdata.jsonl gs://bio-ner_finetuning/train_combined_NERdata.jsonl
# !gsutil cp ./test256_combined_NERdata.jsonl gs://bio-ner_finetuning/test256_combined_NERdata.jsonl

# %%
if client.vertexai:
    training_dataset = types.TuningDataset(
        gcs_uri='gs://bio-ner_finetuning/train_combined_NERdata.jsonl',
    )
    validation_dataset = types.TuningValidationDataset(
        gcs_uri='gs://bio-ner_finetuning/test256_combined_NERdata.jsonl'
    )

    tuning_job = client.tunings.tune(
      base_model='gemini-1.5-flash-002',
      training_dataset=training_dataset,
      config=types.CreateTuningJobConfig(
          # epoch_count= 0, default
          # learning_rate_multiplier=1, default
          description='Fine tune on cell_line, cell_type, disease, dna, rna, drug_chemical, gene_protein, species',
          adapter_size='ADAPTER_SIZE_EIGHT',
          tuned_model_display_name='bioNER-1.5-flash-002_combined',
          validation_dataset=validation_dataset
    )
)
# Out:
#
#     <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons">
#     <style>
#       .view-vertex-resource,
#       .view-vertex-resource:hover,
#       .view-vertex-resource:visited {
#         position: relative;
#         display: inline-flex;
#         flex-direction: row;
#         height: 32px;
#         padding: 0 12px;
#           margin: 4px 18px;
#         gap: 4px;
#         border-radius: 4px;
#
#         align-items: center;
#         justify-content: center;
#         background-color: rgb(255, 255, 255);
#         color: rgb(51, 103, 214);
#
#         font-family: Roboto,"Helvetica Neue",sans-serif;
#         font-size: 13px;
#         font-weight: 500;
#         text-transform: uppercase;
#         text-decoration: none !important;
#
#         transition: box-shadow 280ms cubic-bezier(0.4, 0, 0.2, 1) 0s;
#         box-shadow: 0px 3px 1px -2px rgba(0,0,0,0.2), 0px 2px 2px 0px rgba(0,0,0,0.14), 0px 1px 5px 0px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active {
#         box-shadow: 0px 5px 5px -3px rgba(0,0,0,0.2),0px 8px 10px 1px rgba(0,0,0,0.14),0px 3px 14px 2px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active .view-vertex-ripple::before {
#         position: absolute;
#         top: 0;
#         bottom: 0;
#         left: 0;
#         right: 0;
#         border-radius: 4px;
#         pointer-events: none;
#
#         content: '';
#         background-color: rgb(51, 103, 214);
#         opacity: 0.12;
#       }
#       .view-vertex-icon {
#         font-size: 18px;
#       }
#     </style>
#
#         <a class="view-vertex-resource" id="view-vertex-resource-6df6e5e6-7534-4f81-9a47-0e48c835753d" href="#view-view-vertex-resource-6df6e5e6-7534-4f81-9a47-0e48c835753d">
#           <span class="material-icons view-vertex-icon">tune</span>
#           <span>View Tuning Job</span>
#         </a>
#
#         <script>
#           (function () {
#             const link = document.getElementById('view-vertex-resource-6df6e5e6-7534-4f81-9a47-0e48c835753d');
#             link.addEventListener('click', (e) => {
#               if (window.google?.colab?.openUrl) {
#                 window.google.colab.openUrl('https://console.cloud.google.com/vertex-ai/generative/language/locations/us-east4/tuning/tuningJob/3653763450762428416?project=782077915176');
#               } else {
#                 window.open('https://console.cloud.google.com/vertex-ai/generative/language/locations/us-east4/tuning/tuningJob/3653763450762428416?project=782077915176', '_blank');
#               }
#               e.stopPropagation();
#               e.preventDefault();
#             });
#           })();
#         </script>

# %%
if client.vertexai:
    training_dataset = types.TuningDataset(
        gcs_uri='gs://bio-ner_finetuning/train_combined_NERdata.jsonl',
    )
    validation_dataset = types.TuningValidationDataset(
        gcs_uri='gs://bio-ner_finetuning/test256_combined_NERdata.jsonl'
    )

    tuning_job = client.tunings.tune(
      base_model='gemini-1.5-pro-002',
      training_dataset=training_dataset,
      config=types.CreateTuningJobConfig(
          epoch_count= 10,
          # learning_rate_multiplier=1, default
          description='Fine tune on cell_line, cell_type, disease, dna, rna, drug_chemical, gene_protein, species',
          adapter_size='ADAPTER_SIZE_FOUR',
          tuned_model_display_name='bioNER-1.5-pro-002_combined',
          validation_dataset=validation_dataset
    )
)
# Out:
#
#     <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons">
#     <style>
#       .view-vertex-resource,
#       .view-vertex-resource:hover,
#       .view-vertex-resource:visited {
#         position: relative;
#         display: inline-flex;
#         flex-direction: row;
#         height: 32px;
#         padding: 0 12px;
#           margin: 4px 18px;
#         gap: 4px;
#         border-radius: 4px;
#
#         align-items: center;
#         justify-content: center;
#         background-color: rgb(255, 255, 255);
#         color: rgb(51, 103, 214);
#
#         font-family: Roboto,"Helvetica Neue",sans-serif;
#         font-size: 13px;
#         font-weight: 500;
#         text-transform: uppercase;
#         text-decoration: none !important;
#
#         transition: box-shadow 280ms cubic-bezier(0.4, 0, 0.2, 1) 0s;
#         box-shadow: 0px 3px 1px -2px rgba(0,0,0,0.2), 0px 2px 2px 0px rgba(0,0,0,0.14), 0px 1px 5px 0px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active {
#         box-shadow: 0px 5px 5px -3px rgba(0,0,0,0.2),0px 8px 10px 1px rgba(0,0,0,0.14),0px 3px 14px 2px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active .view-vertex-ripple::before {
#         position: absolute;
#         top: 0;
#         bottom: 0;
#         left: 0;
#         right: 0;
#         border-radius: 4px;
#         pointer-events: none;
#
#         content: '';
#         background-color: rgb(51, 103, 214);
#         opacity: 0.12;
#       }
#       .view-vertex-icon {
#         font-size: 18px;
#       }
#     </style>
#
#         <a class="view-vertex-resource" id="view-vertex-resource-4ed8d3cf-f504-46eb-a235-0aebd1526b52" href="#view-view-vertex-resource-4ed8d3cf-f504-46eb-a235-0aebd1526b52">
#           <span class="material-icons view-vertex-icon">tune</span>
#           <span>View Tuning Job</span>
#         </a>
#
#         <script>
#           (function () {
#             const link = document.getElementById('view-vertex-resource-4ed8d3cf-f504-46eb-a235-0aebd1526b52');
#             link.addEventListener('click', (e) => {
#               if (window.google?.colab?.openUrl) {
#                 window.google.colab.openUrl('https://console.cloud.google.com/vertex-ai/generative/language/locations/us-east4/tuning/tuningJob/646484799585779712?project=782077915176');
#               } else {
#                 window.open('https://console.cloud.google.com/vertex-ai/generative/language/locations/us-east4/tuning/tuningJob/646484799585779712?project=782077915176', '_blank');
#               }
#               e.stopPropagation();
#               e.preventDefault();
#             });
#           })();
#         </script>

# %% [markdown]
# # References
# 1. [BERN2: an advanced neural biomedical named entity recognition and normalization tool](https://arxiv.org/abs/2201.02080)
# 1. [PromptNER: Prompting For Named Entity Recognition](https://arxiv.org/abs/2305.15444)
# 1. [GPT-NER: Named Entity Recognition via Large Language Models](https://arxiv.org/abs/2304.10428)
